# %% [markdown]
# # Finnish Lastname Generator

# %% [markdown]
# <img src="sukunimet.jpg">

# %% [markdown]
# Have you ever wondered what would be your name or surname if you were born in another country? During last two years when I have been living in Finland this question came to my mind several times. Once I even used online generator to get myself a Finnish name and surname. Visit http://www.visitfinland.com/campaigns/finngenerator/public/en/ to check it out.
#
# However, after getting familiar with Sequential models I thought that it should be possible to use one of those to teach it to generate new surnames which would resemble already existing ones. To train such a model we would need a dataset of original Finnish lastnames. I found such at http://tuomas.salste.net/suku/nimi/index-en.html. It consists of 23,166 family names found in Finland.
#
# Let's get started!

# %%
import numpy as np
from utils import *
import random

# %% [markdown]
# ### 1 - Dataset and Preprocessing
#
# Run the following cell to read the dataset of Finnish surnames, create a list of unique characters (such as a-z), and compute the dataset and vocabulary size.

# %%
data = open('finnish_lastnames.txt', 'r', encoding='latin-1').read()
data= data.lower()
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('There are %d total characters and %d unique characters in your data.' % (data_size, vocab_size))
print('Characters are ', chars)
# Out:
# There are 154642 total characters and 29 unique characters in your data.
# Characters are  ['c', 'b', 'h', 'm', 'p', 'r', 'f', 'e', 'y', '\n', 'é', 'u', 'k', 'i', 't', 'ü', 'ä', 'v', '-', 'd', 'ö', 'l', 'a', 'w', 'j', 'g', 'o', 's', 'n']

# %% [markdown]
# The "\n" (or newline character) indicates the end of the surname rather than the end of a sentence. In the cell below, we create a python dictionary (i.e., a hash table) to map each character to an index from 0-38. We also create a second python dictionary that maps each index back to the corresponding character. This will help you figure out what index corresponds to what character in the probability distribution output of the softmax layer. Below, char_to_ix and ix_to_char are the python dictionaries.

# %%
char_to_ix = { ch:i for i,ch in enumerate(sorted(chars)) }
ix_to_char = { i:ch for i,ch in enumerate(sorted(chars)) }
print(ix_to_char)
# Out:
# {0: '\n', 1: '-', 2: 'a', 3: 'b', 4: 'c', 5: 'd', 6: 'e', 7: 'f', 8: 'g', 9: 'h', 10: 'i', 11: 'j', 12: 'k', 13: 'l', 14: 'm', 15: 'n', 16: 'o', 17: 'p', 18: 'r', 19: 's', 20: 't', 21: 'u', 22: 'v', 23: 'w', 24: 'y', 25: 'ä', 26: 'é', 27: 'ö', 28: 'ü'}

# %% [markdown]
# ### 2 - Overview of the model
#
# Your model will have the following structure:
#
# - Initialize parameters
# - Run the optimization loop
#     - Forward propagation to compute the loss function
#     - Backward propagation to compute the gradients with respect to the loss function
#     - Clip the gradients to avoid exploding gradients
#     - Using the gradients, update your parameter with the gradient descent update rule.
# - Return the learned parameters

# %% [markdown]
# We will write two helper functions. One that clips gradient values which helps to avoid exploding gradient problem. Another samples a sequence of characters according to a sequence of probability distributions output of the RNN.

# %%
def clip(gradients, maxValue):
    '''
    Clips the gradients' values between minimum and maximum.
    
    Arguments:
    gradients -- a dictionary containing the gradients "dWaa", "dWax", "dWya", "db", "dby"
    maxValue -- everything above this number is set to this number, and everything less than -maxValue is set to -maxValue
    
    Returns: 
    gradients -- a dictionary with the clipped gradients.
    '''
    
    dWaa, dWax, dWya, db, dby = gradients['dWaa'], gradients['dWax'], gradients['dWya'], gradients['db'], gradients['dby']
   
    # clip to mitigate exploding gradients, loop over [dWax, dWaa, dWya, db, dby]. (≈2 lines)
    for gradient in [dWax, dWaa, dWya, db, dby]:
        np.clip(gradient, -maxValue, maxValue, out=gradient)
    
    gradients = {"dWaa": dWaa, "dWax": dWax, "dWya": dWya, "db": db, "dby": dby}
    
    return gradients

# %%
def sample(parameters, char_to_ix, seed):
    """
    Sample a sequence of characters according to a sequence of probability distributions output of the RNN

    Arguments:
    parameters -- python dictionary containing the parameters Waa, Wax, Wya, by, and b. 
    char_to_ix -- python dictionary mapping each character to an index.
    seed -- used for grading purposes. Do not worry about it.

    Returns:
    indices -- a list of length n containing the indices of the sampled characters.
    """
    
    # Retrieve parameters and relevant shapes from "parameters" dictionary
    Waa, Wax, Wya, by, b = parameters['Waa'], parameters['Wax'], parameters['Wya'], parameters['by'], parameters['b']
    vocab_size = by.shape[0]
    n_a = Waa.shape[1]
    
    # Step 1: Create the one-hot vector x for the first character (initializing the sequence generation). (≈1 line)
    x = np.zeros(vocab_size)
    # Step 1': Initialize a_prev as zeros (≈1 line)
    a_prev = np.zeros((n_a))
    
    # Create an empty list of indices, this is the list which will contain the list of indices of the characters to generate (≈1 line)
    indices = []
    
    # Idx is a flag to detect a newline character, we initialize it to -1
    idx = -1 
    
    # Loop over time-steps t. At each time-step, sample a character from a probability distribution and append 
    # its index to "indices". We'll stop if we reach 50 characters (which should be very unlikely with a well 
    # trained model), which helps debugging and prevents entering an infinite loop. 
    counter = 0
    newline_character = char_to_ix['\n']
    
    while (idx != newline_character and counter != 50):
        
        # Step 2: Forward propagate x using the equations (1), (2) and (3)
        a = np.tanh(np.dot(Wax, x) + np.dot(Waa, a_prev) + b)
        z = np.dot(Wya, a) +  by 
        y = softmax(z)
        
        # for grading purposes
        np.random.seed(counter+seed) 
        
        # Step 3: Sample the index of a character within the vocabulary from the probability distribution y
        idx = np.random.choice(list(range(vocab_size)), p = y[:, counter].ravel())

        # Append the index to "indices"
        indices.append(idx)
        
        # Step 4: Overwrite the input character as the one corresponding to the sampled index.
        x = np.zeros((vocab_size, 1))
        x[idx] = 1
        
        # Update "a_prev" to be "a"
        a_prev = a
        
        # for grading purposes
        seed += 1
        counter +=1

    if (counter == 50):
        indices.append(char_to_ix['\n'])
    
    return indices

# %% [markdown]
# Next we will implement a function performing one step of stochastic gradient descent (with clipped gradients). You will go through the training examples one at a time, so the optimization algorithm will be stochastic gradient descent.

# %%
def optimize(X, Y, a_prev, parameters, learning_rate = 0.01):
    """
    Execute one step of the optimization to train the model.
    
    Arguments:
    X -- list of integers, where each integer is a number that maps to a character in the vocabulary.
    Y -- list of integers, exactly the same as X but shifted one index to the left.
    a_prev -- previous hidden state.
    parameters -- python dictionary containing:
                        Wax -- Weight matrix multiplying the input, numpy array of shape (n_a, n_x)
                        Waa -- Weight matrix multiplying the hidden state, numpy array of shape (n_a, n_a)
                        Wya -- Weight matrix relating the hidden-state to the output, numpy array of shape (n_y, n_a)
                        b --  Bias, numpy array of shape (n_a, 1)
                        by -- Bias relating the hidden-state to the output, numpy array of shape (n_y, 1)
    learning_rate -- learning rate for the model.
    
    Returns:
    loss -- value of the loss function (cross-entropy)
    gradients -- python dictionary containing:
                        dWax -- Gradients of input-to-hidden weights, of shape (n_a, n_x)
                        dWaa -- Gradients of hidden-to-hidden weights, of shape (n_a, n_a)
                        dWya -- Gradients of hidden-to-output weights, of shape (n_y, n_a)
                        db -- Gradients of bias vector, of shape (n_a, 1)
                        dby -- Gradients of output bias vector, of shape (n_y, 1)
    a[len(X)-1] -- the last hidden state, of shape (n_a, 1)
    """
    
    # Forward propagate through time (≈1 line)
    loss, cache = rnn_forward(X, Y, a_prev, parameters)
    
    # Backpropagate through time (≈1 line)
    gradients, a = rnn_backward(X, Y, parameters, cache)
    
    # Clip your gradients between -5 (min) and 5 (max) (≈1 line)
    gradients = clip(gradients, 5)
    
    # Update parameters (≈1 line)
    parameters = update_parameters(parameters, gradients, learning_rate)
    
    ### END CODE HERE ###
    
    return loss, gradients, a[len(X)-1]

# %% [markdown]
# ### 3 - Training the model
#
# Given the dataset of Finnish surnames, we use each line of the dataset (one surname) as one training example. Every 100 steps of stochastic gradient descent, you will sample 10 randomly chosen surnames to see how the algorithm is doing. Remember to shuffle the dataset, so that stochastic gradient descent visits the examples in random order.

# %%
def model(data, ix_to_char, char_to_ix, num_iterations = 500000, n_a = 50, surnames = 10, vocab_size = 29):
    """
    Trains the model and generates dinosaur names. 
    
    Arguments:
    data -- text corpus
    ix_to_char -- dictionary that maps the index to a character
    char_to_ix -- dictionary that maps a character to an index
    num_iterations -- number of iterations to train the model for
    n_a -- number of units of the RNN cell
    surnames -- number of Finnish surnames you want to sample at each iteration. 
    vocab_size -- number of unique characters found in the text, size of the vocabulary
    
    Returns:
    parameters -- learned parameters
    """
    
    print('n_a',n_a)
    
    # Retrieve n_x and n_y from vocab_size
    n_x, n_y = vocab_size, vocab_size
    
    # Initialize parameters
    parameters = initialize_parameters(n_a, n_x, n_y)
    
    # Initialize loss (this is required because we want to smooth our loss, don't worry about it)
    loss = get_initial_loss(vocab_size, surnames)
    
    # Build list of all dinosaur names (training examples).
    with open("finnish_lastnames.txt", encoding='latin-1') as f:
        examples = f.readlines()
    examples = [x.lower().strip() for x in examples]
    
    # Shuffle list of all dinosaur names
    np.random.seed(0)
    np.random.shuffle(examples)
    
    # Initialize the hidden state of your LSTM
    a_prev = np.zeros((n_a, 1))
    
    # Optimization loop
    for j in range(num_iterations):
        
        ### START CODE HERE ###

        # Use the hint above to define one training example (X,Y) (≈ 2 lines)
        index = j % len(examples)
        X = [None] + [char_to_ix[ch] for ch in examples[index]] 
        Y = X[1:] + [char_to_ix["\n"]]
        
        # Perform one optimization step: Forward-prop -> Backward-prop -> Clip -> Update parameters
        # Choose a learning rate of 0.01
        
        curr_loss, gradients, a_prev = optimize(X, Y, a_prev, parameters, learning_rate=0.01)
        
        ### END CODE HERE ###
        
        # Use a latency trick to keep the loss smooth. It happens here to accelerate the training.
        loss = smooth(loss, curr_loss)

        # Every 2000 Iteration, generate "n" characters thanks to sample() to check if the model is learning properly
        if j % 2000 == 0:
            
            print('Iteration: %d, Loss: %f' % (j, loss) + '\n')
            
            # The number of dinosaur names to print
            seed = 0
            for name in range(surnames):
                
                # Sample indices and print them
                sampled_indices = sample(parameters, char_to_ix, seed)
                print_sample(sampled_indices, ix_to_char)
                
                seed += 1  # To get the same result for grading purposed, increment the seed by one. 
      
            print('\n')
        
    return parameters

# %%
parameters = model(data, ix_to_char, char_to_ix)
# Out:
# n_a 50
# Iteration: 0, Loss: 33.686429
#
# Nküäävcmerpeögury-ujjiyv
# Knea
# Küäävcmerpeögury-ujjiyv
# Nea
# Üäävcmerpeögury-ujjiyv
# Ea
# Äävcmerpeögury-ujjiyv
# A
# Ävcmerpeögury-ujjiyv
#
#
#
# Iteration: 2000, Loss: 24.683657
#
# Mivvurakenlaulolu
# Kka
# Käturakenlaulolu
# Md
# Äturakenlaulolu
# E
# Uttalalmaukontanilertaltiyla
# -
# Uralalmaukontanilertaltiyla
#
#
#
# Iteration: 4000, Loss: 21.632903
#
# Mewtvo
# Kka
# Läturaijko
# Ma
# Ätusalajnevanku
# Ha
# Uttalago
# A
# Usalako
#
#
#
# Iteration: 6000, Loss: 20.293826
#
# Nevtunen
# Leja
# Lätupala
# Nei
# Wuutalaanetalikanen
# Iaahsta
# Uttakali
# A
# Ttaikmi
#
#
#
# Iteration: 8000, Loss: 19.629378
#
# Netturanen
# Lela
# Lätto
# Nel
# Yuttamamkasinen
# Jaalosi
# Uutamanmatkolo
# Aalori
# Tukkanietimoranilalo
# Aitti
#
#
# Iteration: 10000, Loss: 19.317964
#
# Nevvurajallatinirankalri
# Liikakorha
# Läusramallatimio
# Neja-rula
# Ysto-karnatanni
# Jaalko
# Vusamalkatileranjakon
# Aakora
# Utilakkasanmä
# Ajttaa
#
#
# Iteration: 12000, Loss: 18.960299
#
# Nettuo
# Leijaaro
# Lävären
# Nek
# Ysto
# Jaakko
# Uusala
# Aakora
# Tujokko
# Aistea
#
#
# Iteration: 14000, Loss: 18.589429
#
# Moutupahe
# Leijahpo
# Läuttala
# Maa
# Yturamaa
# Jaajora
# Uusala
# Eakosea
# Uukkanmatko
# Ahto
#
#
# Iteration: 16000, Loss: 18.517189
#
# Pmöturanga
# Leijainiekakontaa
# Läytä-nerlaumoinan
# Pei-erta
# Ysypenghi
# Jaajus
# Uusamangas
# Aajps
# Usilalmas
# Ajutja
#
#
# Iteration: 18000, Loss: 18.655028
#
# Mivtuo
# Lika
# Lävyriijo
# Mehajäri
# Yturanen
# Jaajori
# Vuukkaniaumolra
# Eajtti
# Tukkanietinis
# Ahtti-altopaa
#
#
# Iteration: 20000, Loss: 18.227822
#
# Leutto
# Kki-ahora
# Käystamaa
# Lahahonem
# Ystu
# Haahosaa
# Vuokkanen
# Aajosaa
# Usanen
# Aista
#
#
# Iteration: 22000, Loss: 18.004535
#
# Olvuska
# Laha
# Läyväinen
# Ola
# Yyväimmi
# Ieemäli
# Uusalaapaulinkapi
# Aahto
# Uukkala
# Aerte
#
#
# Iteration: 24000, Loss: 18.057439
#
# Pivustahi
# Liikahokka
# Läväri
# Pehakori
# Ystrenen
# Kaajusia
# Vuukkanieti
# Hahtsaaaro
# Uukkangaunsiranjakon
# Alori
#
#
# Iteration: 26000, Loss: 18.152516
#
# Mautto
# Lehe
# Läutsala
# Maa
# Yvärala
# Iehintaa
# Uusala
# Aajora
# Tuinen
# Ahtoha
#
#
# Iteration: 28000, Loss: 18.066573
#
# Mautto
# Lila
# Läväralenahulo
# Mahairsa
# Ysvtala
# Haakko
# Uusalaapasanno
# Aaltta
# Tullanieu
# Ahtte
#
#
# Iteration: 30000, Loss: 17.692217
#
# Omutto
# Liika
# Lättä
# Ola
# Yyttiejo
# Haalko
# Vutmia
# Aajore
# Usilahtanjo
# Ahtti
#
#
# Iteration: 32000, Loss: 17.722990
#
# Onttynen
# Lika
# Lävärho
# Ola
# Ytäri
# Iehinsaa
# Uutanen
# Aajosaa
# Uukkankaummi
# Ahto
#
#
# Iteration: 34000, Loss: 17.812808
#
# Mautto
# Kika
# Lävärbi
# Maahanta
# Ysto
# Haajora
# Turimainen
# Aajora
# Toilamoara
# Ahtla
#
#
# Iteration: 36000, Loss: 17.974906
#
# Livusmie
# Kola
# Läusnala
# Lehakku
# Ysty
# Kaalisaa
# Uus
# Hakora
# Tulmanen
# Aisti
#
#
# Iteration: 38000, Loss: 17.908418
#
# Piytyrho
# Lii
# Läväpen
# Pehakoski
# Yturanniemä
# Kaalko
# Uusanen
# Hahtte
# Toininies
# Ajusa
#
#
# Iteration: 40000, Loss: 17.600630
#
# Onttto
# Lii
# Läytti
# Ola
# Vuusala
# Haakosaahaaro
# Tusala
# Aakosaahaaro
# Tukkami
# Ajura
#
#
# Iteration: 42000, Loss: 17.645167
#
# Piätären
# Liihaari
# Lätärakangau
# Pehakoski
# Ysämaa
# Kaajosaa
# Uusalaanas
# Eelosehalti
# Usalahti
# Aissea
#
#
# Iteration: 44000, Loss: 17.725192
#
# Pettuo
# Likhakoski
# Lästuhelnietinen
# Peihapula
# Yttähkinketonen
# Kaakkola
# Turjo
# Hajora
# Tukkimäkvensu
# Aloska
#
#
# Iteration: 46000, Loss: 17.830001
#
# Peusto
# Lehdaantee
# Lästyjäinen
# Paahanpeh
# Ysto
# Kaakosaa
# Uusela
# Bajopaa
# Tulojildu
# Ajonen
#
#
# Iteration: 48000, Loss: 17.471618
#
# Piätys
# Liikajärvi
# Mäuvä
# Paahaosaa
# Yväri
# Kaakko
# Uusemaa
# Eakosaa
# Uukkanehvantsala
# Ajoha
#
#
# Iteration: 50000, Loss: 17.526402
#
# Piötänen
# Lild
# Läättikermari
# Peiemutka
# Ytty
# Kaalis
# Uutala
# Aalonen
# Tullankas
# Ahto
#
#
# Iteration: 52000, Loss: 17.584665
#
# Leutsu
# Kola
# Käytykkangavaari
# Lahajärti
# Yväsala
# Kaajonen
# Tutalahtes
# Eajonen
# Suinenkaunen
# Ahto
#
#
# Iteration: 54000, Loss: 17.575152
#
# Neväsrankkelä
# Lika
# Löyttola
# Neiemäri
# Ystä
# Kaakora
# Tyykkymäkä
# Haitta
# Tulmannevi
# Alora
#
#
# Iteration: 56000, Loss: 17.559330
#
# Piäsynen
# Loka
# Läyvä
# Pehajärs
# Yväre
# Kaajonen
# Uusamaa
# Aajonen
# Tullampari
# Airo
#
#
# Iteration: 58000, Loss: 17.665944
#
# Piätynen
# Moka
# Määty
# Paahanla
# Yyvä
# Kaahonen
# Uutanen
# Haitte
# Tuinenlala
# Alopea
#
#
# Iteration: 60000, Loss: 17.619179
#
# Poutto
# Lehda
# Läuttela
# Peiherva
# Ytvä
# Kaalisaa
# Tyrkkunies
# A
# Sullannetsolo
# Aiste
#
#
# Iteration: 62000, Loss: 17.474148
#
# Poutto
# Lika
# Läuttemala
# Peihanoja
# Ysyrainen
# Kaakkola
# Uusila
# Haitti
# Tuipilä
# Aitti
#
#
# Iteration: 64000, Loss: 17.521816
#
# Peutun
# Liijakko
# Lästo
# Paahansa
# Yrvi
# Kaajanen
# Tuukkala
# A
# Suinenmau
# Alosaa
#
#
# Iteration: 66000, Loss: 17.341052
#
# Pivostie
# Leha
# Mätvä
# Paahapuo
# Yrvi
# Kaakos
# Turenjärpu
# Aajis
# Suipenneumpi
# Aistea
#
#
# Iteration: 68000, Loss: 17.425861
#
# Piätunen
# Mula
# Mätätalakkasanppaala
# Pehakko
# Ysti-karnaunen
# Kaalisaa
# Tutamailarikko
# Aalis
# Tulijuo
# Ahto-aarsio
#
#
# Iteration: 70000, Loss: 17.435551
#
# Metturannikas
# Kki-alonen
# Kyvätki
# Madakko
# Ystä
# Kahinla
# Turjo
# Hajppi
# Tullenmas
# Aloma
#
#
# Iteration: 72000, Loss: 17.328373
#
# Pivusti
# Lime
# Mätäsaljuo
# Pehalami
# Ystä
# Haakosei
# Vuokkanen
# Aamori
# Useniinen
# Airo
#
#
# Iteration: 74000, Loss: 17.267922
#
# Piutto
# Mike
# Mätäs
# Peiemys
# Yttukero
# Kaakosaa
# Väsila
# Eempsaa
# Uulkenkevainen
# Akosaa
#
#
# Iteration: 76000, Loss: 17.250138
#
# Onutto
# Liijakoski
# Läyty
# Oja
# Ytänen
# Kaakora
# Tyväläinen
# Haeste
# Tukkala
# Ainola
#
#
# Iteration: 78000, Loss: 17.301327
#
# Ontsonen
# Leijakoski
# Läväs
# Ola
# Yvärala
# Kaakko
# Tysjä
# Aalosaahio
# Tukkamo
# Alosaahjo
#
#
# Iteration: 80000, Loss: 17.335755
#
# Piätto
# Liijahopaa
# Mätärala
# Paahanne
# Ysuo
# Kaakora
# Tytli-pokula
# Eelonen
# Suirankauipir-olahto
# Alooka
#
#
# Iteration: 82000, Loss: 17.332876
#
# Pivuro
# Meka
# Outto
# Pehajärvi
# Yrvo
# Kaakoola
# Uusimaaharilin
# Haesti
# Tukkanen
# Aitti
#
#
# Iteration: 84000, Loss: 17.271844
#
# Piytupainen
# Lehdajärvi
# Läuttamaa
# Pehajärvi
# Yuttalahti
# Kaakko
# Tyykkinensansä
# Hahtoiejo
# Tuisjynes
# Ahtoja
#
#
# Iteration: 86000, Loss: 17.288595
#
# Poutupangas
# Niikalo
# Outupangas
# Pehajorka
# Ysupangas
# Kaalio
# Turamaa
# Hajoraa
# Sukkala
# Aisti
#
#
# Iteration: 88000, Loss: 17.436704
#
# Peusto
# Mele
# Mättäjäki
# Paahansaa
# Ysttela
# Kaakoola
# Svihjanniuri
# Haiste
# Sulkanmaniiri
# Ahpola
#
#
# Iteration: 90000, Loss: 17.355461
#
# Piättä
# Liihahonel
# Läytti-hikhu
# Paadaro
# Yrko
# Jaainpaa
# Turhi
# Hairni
# Ttelamaari
# Aitte
#
#
# Iteration: 92000, Loss: 17.062348
#
# Olvonsala
# Like
# Möyty
# Oka
# Vustala
# Kaakori
# Tuukkala
# Hahtuela
# Sukkala
# Almoja
#
#
# Iteration: 94000, Loss: 17.188035
#
# Ppästvaha
# Lika
# Läyttikangatio
# Pehakoski
# Yrvujäki
# Kaakosaahola
# Tuukkenietikku
# Hahsoja
# Tukkangauppora
# Alooja
#
#
# Iteration: 96000, Loss: 17.281038
#
# Petäänen
# Lehhahorja
# Mäsvä
# Paahinla
# Väsvimai
# Kaakkola
# Susenen
# Haasija
# Suipenkauki
# Almikaalkipa
#
#
# Iteration: 98000, Loss: 17.266403
#
# Mettän
# Lile
# Läärä
# Maadenoja
# Väyrilä
# Kaakosaha
# Syrjäkooksalo
# Haisti
# Sukkala
# Alpola
#
#
# Iteration: 100000, Loss: 17.052679
#
# Piätyri
# Lihe
# Mäyvä-oitpasalo
# Pehahts
# Väätimaa
# Jaajonen
# Syvila
# Hahto
# Sylsimo
# Ahtoja
#
#
# Iteration: 102000, Loss: 17.037406
#
# Puutto
# Moka
# Märvä
# Piehinoja
# Väyrikarjala
# Kaakko
# Tyrkkinen
# Haaro
# Suininen
# Aarti
#
#
# Iteration: 104000, Loss: 17.105248
#
# Piutti
# Lehdaari
# Märvihohti
# Paaharte
# Vyttila
# Haakko
# Tyykkimäki
# Hahtoja
# Ttakanen
# Ahtoja
#
#
# Iteration: 106000, Loss: 17.296732
#
# Pautto
# Liihaarte
# Lävpä
# Paahenpaa
# Ytyrangas
# Kaallo
# Syvelaapatio
# Hairo
# Sulkenlauninnen
# Ahtti
#
#
# Iteration: 108000, Loss: 17.300893
#
# Reutus
# Poja
# Pöästenikketkurt
# Raadaokha
# Vuttanen
# Kaalmu
# Suranen
# Hahtula
# Sulijuo
# Aistee
#
#
# Iteration: 110000, Loss: 17.000263
#
# Routtoala
# Muka
# Mästä
# Rahakoski
# Vustalaanauori
# Kaakosaa
# Supenila
# Aahtoka
# Suiramäkky
# Airoja
#
#
# Iteration: 112000, Loss: 17.081263
#
# Puutuo
# Meld
# Märvä
# Piedasoka
# Vuosala
# Laajkoja
# Suojakangponni
# Haipukaappio
# Sukkanen
# Aiste
#
#
# Iteration: 114000, Loss: 17.118853
#
# Peväänen
# Miekalin
# Mätääjä
# Pehakky
# Vääski
# Kaakko
# Syvso
# Haisteekky
# Suikkomau
# Airti
#
#
# Iteration: 116000, Loss: 17.326955
#
# Piäsänen
# Niekala
# Outto
# Pehajärvi
# Yrttela
# Laakora
# Syvinen
# Haasta
# Sukkala
# Aitte
#
#
# Iteration: 118000, Loss: 16.986453
#
# Ravustala
# Poja
# Pöyty
# Raha
# Vuurajaarangaskaaaaholahtipala
# Laakosaha
# Uusikarjasalo
# Hahtoi
# Sujainen
# Aista
#
#
# Iteration: 120000, Loss: 17.073637
#
# Riutti
# Mune
# Nätvä-marsas
# Rahdasti
# Vustala
# Kaakosaahonen
# Tyukkinen
# Hakosaahmylä
# Tuki-pietinio
# Aisti
#
#
# Iteration: 122000, Loss: 17.114753
#
# Pettynen
# Leijaisto
# Märvä
# Paahapula
# Väyreniomari
# Kaajora
# Tuuleami
# Haisto
# Tullanies
# Ajus
#
#
# Iteration: 124000, Loss: 17.256507
#
# Nivornala
# Lika
# Löytykke
# Nehajärvi
# Vääsikka
# Kaakko
# Sytkä
# A
# Sujajokinen
# Airo
#
#
# Iteration: 126000, Loss: 17.255761
#
# Riutti
# One-
# Pöäsä
# Rehakoskha
# Väärilä
# Kaajus
# Tytjäkko
# Haarka
# Sukkanieriinemi
# Aista
#
#
# Iteration: 128000, Loss: 17.212573
#
# Poutti
# Moihajärta
# Mättä-masojäki
# Pehakote
# Vupsala
# Kaakosaa
# Syvinen
# Haatti
# Suirenlavaaro
# Alopaa
#
#
# Iteration: 130000, Loss: 17.149498
#
# Pousto
# Moih
# Mätvä
# Pehalainen
# Väärinen
# Kaakosaahoskpi
# Tääkken
# Haassa
# Sukkanen
# Ajus
# Iteration: 132000, Loss: 17.017431
#
# Pousto
# Miihaanta
# Mäsvy-nikkiuojinen
# Peidennel
# Vääsilä
# Kaalonen
# Tyski-polvanniami
# Haassa
# Sumo
# Akori
#
#
# Iteration: 134000, Loss: 17.216597
#
# Peutula
# Luoi
# Mätynen
# Padakki
# Vättilemmasalo
# Kaakkoja
# Särila
# Iteration: 166000, Loss: 16.945734
#
# Rivsola
# Piekaanta
# Päytä-kerpiverto
# Rehakko
# Vätä-kerpiverto
# Kaakko
# Syukkale
# Haarni
# Suisila
# Ahto
#
#
# Iteration: 168000, Loss: 17.015326
#
# Peusunen
# Moka
# Oturo
# Paahapto
# Väärinen
# Kaakko
# Särilaanatorppaakiinelalevaa
# Haitsa
# Syllinen
# Aiste
#
#
# Iteration: 170000, Loss: 16.840960
#
# Piytätaaho
# Miikaalo
# Mäyty
# Raaakoski
# Vääsila
# Kaakko
# Suukkala
# Hahtoii
# Suisala
# Ahtoja
#
#
# Iteration: 172000, Loss: 16.868448
#
# Riutto
# Onee
# Pöyrä
# Rahahto
# Vuusila
# Kaakko
# Suukkala
# Haarpa
# Sukkampala
# Ahto
#
#
# Iteration: 174000, Loss: 16.952273
#
# Piärynen
# Miiha-run
# Märviheini
# Peia
# Vustamaa
# Haakonen
# Tyykkola
# Hahtija
# Sulaaniatalai
# Ahtokaari
#
#
# Iteration: 176000, Loss: 17.080897
#
# Peutto
# Moka
# Märvi
# Paaherä
# Vustanen
# Kaalko
# Tyrikaro
# Haisti
# Sulikikati
# Aista
#
#
# Iteration: 178000, Loss: 16.966795
#
# Poutto
# Poja
# Pöyttila
# Paahari
# Vuttala
# Kaajosaala
# Syrimaa
# Haaste
# Sulhelhauninpamo
# Aitti
#
#
# Iteration: 180000, Loss: 16.796935
#
# Pousunen
# Mula
# Mätvä
# Peihanma
# Vustala
# Kaakosaahi
# Supala
# Haarni
# Sukkeli
# Aisti
#
#
# Iteration: 182000, Loss: 16.997584
#
# Puuturannen
# Puha
# Päätten
# Piedes
# Vuorenaho
# Laakosaa
# Suola
# Haaroja
# Sukkinen
# Aitti
#
#
# Iteration: 184000, Loss: 17.103731
#
# Reutto
# Peikalahte
# Pääsä-karsatio
# Raidapti
# Vuosamaa
# Kaaknsa
# Syvänala
# Hahtola
# Sukkanen
# Aista
#
#
# Iteration: 186000, Loss: 17.223573
#
# Pivässahen
# Neme
# Oturo
# Pehakoski
# Väärililtes
# Kaakosaa
# Syvänen
# I
# Sulkenkivi
# Alore
#
#
# Iteration: 188000, Loss: 16.867369
#
# Rivustala
# Poja
# Rästoja
# Rahakko
# Vyysku
# Maajos
# Syvalahtinen
# Hahtsa
# Sujakinen
# Ahokaa
#
#
# Iteration: 190000, Loss: 16.887639
#
# Puuttmainen
# Mule
# Mättä
# Pieenniemi
# Vustala
# Kaakos
# Tyykki-launilo
# Haaste
# Tukkala
# Ahtsi
#
#
# Iteration: 192000, Loss: 16.836277
#
# Pettunen
# Miiha
# Märvähohti
# Pehajäru
# Vurtamalaatinen
# Kaakosaa
# Vuolihonkumpi
# Hairo
# Tukkanenaho
# Airoka
#
#
# Iteration: 194000, Loss: 16.931183
#
# Piäränen
# Moii
# Näväransaliverto
# Paahiola
# Vustala
# Kaakorahjo
# Syrilä
# Hahto
# Suisilä
# Ahto
#
#
# Iteration: 196000, Loss: 16.905532
#
# Rivtomaa
# Nielajärvi
# Ottonen
# Rahajärvi
# Väärilä
# Kaakosaa
# Syskä
# Hairo
# Sullamo
# Ahonen
#
#
# Iteration: 198000, Loss: 16.937566
#
# Prästi
# Moih
# Mäyttilä
# Pieelä-kaartio
# Vuorenen
# Kaakosaa
# Supala
# Haasti
# Sukkeri
# Alopaa
#
#
# Iteration: 200000, Loss: 16.988796
#
# Pousuo
# Moiha
# Nyytyahojo
# Pieensul
# Vuorenius
# Kaakosaa
# Surenioojännivankalo
# Haaro
# Sulkamäkmo
# Ahpula
#
#
# Iteration: 202000, Loss: 16.855436
#
# Revuniemi
# Niekalahta
# Otvonen
# Rahaanta
# Vursemallari
# Kaajonen
# Suojo
# Haarni
# Sulikkkinen
# Akusaahio
#
#
# Iteration: 204000, Loss: 17.059897
#
# Piärän
# Miel
# Näränalainen
# Pehakoski
# Värä
# Kaakko
# Syrjä
# Haaste-antirainniemä
# Suininen
# Aiste
#
#
# Iteration: 206000, Loss: 16.778081
#
# Reutuo
# Pole
# Pöytäki
# Raidarune
# Vääsimurpinen
# Kaalonen
# Surenen
# Hakosaamimes
# Suiokorniemil
# Ajute
#
#
# Iteration: 208000, Loss: 16.848836
#
# Pousti
# Mula
# Ottonen
# Paahaola
# Vuttala
# Laakos
# Sytimaa
# Kaitki
# Suinenkaunio
# Aiste
#
#
# Iteration: 210000, Loss: 17.045639
#
# Reuturanta
# Nele
# Oturo
# Rahaanta
# Vutranen
# Kaajonen
# Suokkanen
# Kaispe
# Sukkanen
# Aiste
#
#
# Iteration: 212000, Loss: 16.887166
#
# Pousto
# Niilahto
# Ostonen
# Pehakoski
# Vurtamaa
# Kaantola
# Suramaa
# Haisti
# Sukkanen
# A
#
#
# Iteration: 214000, Loss: 16.813436
#
# Ppävys
# Mule
# Mätötilahti
# Pehakoski
# Vyyttä
# Laamonen
# Suranen
# Kahste
# Suineri
# Ahori
#
#
# Iteration: 216000, Loss: 16.787847
#
# Piytänen
# Miika
# Mätty
# Pehajärvi
# Vuorela
# Laalomaa
# Supila
# Hahtoja
# Suliala
# Aaroa
#
#
# Iteration: 218000, Loss: 16.820959
#
# Pousto
# Miika-pulhalkoti
# Nyytti
# Pieganiemi
# Vuosala
# Kaakko
# Suukkeli
# Haitokaarn
# Sokkala
# Akso
#
#
# Iteration: 220000, Loss: 16.911446
#
# Piätysalo
# Liija
# Mätäransalmperä
# Pehakotka
# Vurtakangas
# Kaakosaahto
# Suo
# Haarki
# Sukkala
# Aisti
#
#
# Iteration: 222000, Loss: 16.974401
#
# Petäsoara
# Niehaari
# Ostonen
# Paahasoja
# Vyytisalo
# Kaakosaa
# Sutala
# Haaro
# Suinenmasaaro
# Ajopaa
#
#
# Iteration: 224000, Loss: 16.759037
#
# Omvistela
# Miijaanta
# Märväjoki
# Oja
# Vuttala
# Kaaliska
# Suokkamo
# Haivola
# Sulikko
# Ahto-aersko
#
#
# Iteration: 226000, Loss: 16.737150
#
# Poutuo
# Poka
# Päätä
# Peihanta
# Vurtalahti
# Kaalio
# Suolaansas
# Jahtoja
# Summanies
# Ahsse
#
#
# Iteration: 228000, Loss: 17.022240
#
# Petääsalmi
# Nieda
# Ottsiala
# Paahanoja
# Vursala
# Laajara
# Sooja
# Hahopaa
# Siinankaun
# Ahoraa
#
#
# Iteration: 230000, Loss: 16.830184
#
# Piäsynen
# Niel
# Ottonen
# Peidenoja
# Vuosala
# Kaakko
# Turikangas
# Haarn
# Tsamanen
# A
#
#
# Iteration: 232000, Loss: 16.617630
#
# Piutunen
# Miejakoski
# Möystemi
# Peidanne
# Vustala
# Kaalora
# Supamaa
# Kairre
# Sulkinen
# Ahtti
#
#
# Iteration: 234000, Loss: 16.798966
#
# Peusko
# Miijallikaari
# Mättä
# Pei
# Vursala
# Kaajonen
# Turi
# Haari
# Ssarinen
# Ahtokaalo
#
#
# Iteration: 236000, Loss: 16.893481
#
# Petätukka
# Moija
# Nyyttihersaukkijainen
# Pehakko
# Vurrammi
# Kaajko
# Susimaa
# Haarniehis
# Suipernetollmadiolmu
# Ahtti
#
#
# Iteration: 238000, Loss: 16.932597
#
# Orvori
# Lili
# Läuttala
# Oka
# Vuttamaa
# Kaakko
# Suukkala
# Hakko
# Sollanen
# Aippi
#
#
# Iteration: 240000, Loss: 16.707878
#
# Miusse
# Luha
# Läyvä
# Meihanoja
# Vussala
# Kaakko
# Suukkalehto
# Haitti-ahtinen
# Sukkala
# Aarka
#
#
# Iteration: 242000, Loss: 16.751333
#
# Petässaljo
# Maijajärvi
# Märänen
# Paahenta
# Vuttamaa
# Kaalonen
# Suukkanen
# Haiste
# Sollanen
# Aarta
#
#
# Iteration: 244000, Loss: 16.788194
#
# Pivuro
# Moke
# Märvienen
# Peihanhaha
# Vuttamaa
# Kaajonen
# Tyukkimäko
# Hahtola
# Sulmanen
# Ahso
#
#
# Iteration: 246000, Loss: 16.988388
#
# Peutunen
# Nielajärvi
# Osvio
# Paahaori
# Vustamaa
# Kaallila
# Uusijaki
# Haaroaaho
# Tukijärvu
# A
#
#
# Iteration: 248000, Loss: 16.880065
#
# Piäpyranta
# Ppihakoski
# Pöyttilhoner
# Pehakoski
# Vutsala
# Kaajas
# Suranen
# Kalpula
# Sullankeviistala
# Aitte
#
#
# Iteration: 250000, Loss: 16.653913
#
# Poutunen
# Moika
# Nyyttilinies
# Paahanka
# Vurtala
# Kaantuka
# Suppi
# Haasta
# Sukkala
# Ahtukaari
#
#
# Iteration: 252000, Loss: 16.846019
#
# Pousto
# Orad
# Pääsoja
# Pehaisti
# Vusteri
# Kaappo
# Supanen
# Haarmaa
# Suisinen
# Aisti
#
#
# Iteration: 254000, Loss: 16.944494
#
# Pivurma
# Pieia
# Pöytula
# Paaherti
# Vääsinen
# Kaakora
# Tyrkkilä
# Hahtikaa
# Tykkilä
# Ahtti
#
#
# Iteration: 256000, Loss: 17.076239
#
# Piäränen
# Mole
# Näsänen
# Pehakoski
# Väuski
# Kaakosaa
# Tysiluomanko
#
#
# Iteration: 288000, Loss: 16.704412
#
# Pousto
# Niehakoski
# Ovronen
# Paahiola
# Vuotala
# Kaalopa
# Susamaa
# Haassa
# Siesilä
# Ahoraa
#
#
# Iteration: 290000, Loss: 16.719618
#
# Kavpola
# Keli
# Kätäpalkki
# Kaahanoja
# Uuttakangas
# Kaakosaa
# Supakangas
# Jahto-aahtera
# Suhohen
# Airo
#
#
# Iteration: 292000, Loss: 16.879126
#
# Peytävahelä
# Miehajärvi
# Möustala
# Paahionen
# Vääsis
# Kaalosaami
# Syrinen
# Haaroja
# Sulikosku
# Ahppeejäynukantie
#
#
# Iteration: 294000, Loss: 16.678120
#
# Mettäsala
# Kengakoski
# Läytä
# Maaahto
# Vuutalahti
# Kaakko
# Tyykkilä
# Hahtla
# Suhrankaukkko
# Ahtoja
#
#
# Iteration: 296000, Loss: 16.750779
#
# Poutto
# One
# Outto
# Peidensaalepirja
# Vytti
# Kaammo
# Syriki
# Haitti
# Sukkala
# Ahtoi
#
#
# Iteration: 298000, Loss: 16.902853
#
# Petäynen
# Melhajärma
# Märväkka
# Peihmänen
# Värtimerpahi
# Kaalno
# Syrilä
# Haarti
# Sullenmetorpo
# Aitula
#
#
# Iteration: 300000, Loss: 16.748061
#
# Piästö
# Miha
# Mätäranta
# Peidinne
# Vurtamern
# Kaamio
# Tyrila
# Haesta
# Sulkimo
# Airo
#
#
# Iteration: 302000, Loss: 16.542220
#
# Mettunen
# Kila
# Köytä
# Mahakoski
# Vuorala
# Kaakonen
# Surala
# Hairsi
# Sukkala
# Ahto
#
#
# Iteration: 304000, Loss: 16.699373
#
# Piutto
# Orja
# Pöuttenen
# Pehakoski
# Västenen
# Kaakosaahi
# Tyrinen
# Hahtikaari
# Soikkonen
# Deste
#
#
# Iteration: 306000, Loss: 16.717662
#
# Piutto
# Omaa
# Pöyty
# Pehakoski
# Vyysilä
# Kaakno
# Surenen
# Haaste
# Sukkamäki
# Ahtoha
#
#
# Iteration: 308000, Loss: 16.752514
#
# Onuste
# Llaha
# Mätvä-marsataro
# Oka
# Vustamaa
# Kaakko
# Suukkamäkk
# Haitsa-alranen
# Sulikka
# Aippa
#
#
# Iteration: 310000, Loss: 16.619135
#
# Okyvuokjarvin
# Mieka
# Mättä
# Oja
# Vurtalaanamaaju
# Kaalopaa
# Tyvirinen
# E
# Sulkamo
# Aaro
#
#
# Iteration: 312000, Loss: 16.749889
#
# Piutto
# Mela
# Mötöranta
# Paahanen
# Vuttela
# Kaalonen
# Tyrjäkky
# Haitti
# Sollanen
# Ahtoja
#
#
# Iteration: 314000, Loss: 16.710680
#
# Petäväinen
# Mihd
# Märvy
# Paahanmaa
# Vustala
# Kaajonen
# Tyskäjärtvirtta
# Hahtokaari
# Sulahoikumpi
# Ahtokaari
#
#
# Iteration: 316000, Loss: 16.875629
#
# Piäsyri
# Orja
# Outto
# Pehakoski
# Vustamaa
# Maaknoikalo
# Tyrikerpi
# Kahro
# Sulikosko
# Airo
#
#
# Iteration: 318000, Loss: 16.777282
#
# Poutto
# Ppihakoski
# Pöuttala
# Pehakoski
# Vutsanen
# Maajonen
# Suunialaatari
# Kajonen
# Sulkinies
# Aiste
#
#
# Iteration: 320000, Loss: 16.534444
#
# Pivusmaa
# Miika-pulhakorpi
# Mättö
# Peienpää
# Vustakangas
# Kaappo
# Susenen
# Kahtia
# Sukkala
# Airti
#
#
# Iteration: 322000, Loss: 16.769529
#
# Reutto
# Ori
# Pötäs
# Raed
# Uutten
# Laalosaahosko
# Suranen
# Kaisti
# Suipara
# Airra
#
#
# Iteration: 324000, Loss: 16.771264
#
# Petäspalen
# Mulha-runkamäki
# Mästä
# Pahaknmaahosano
# Tyytilä
# Kaammo
# Tytilo
# Kaitti
# Suirila
# Aitti
#
#
# Iteration: 326000, Loss: 16.874070
#
# Orvuola
# Mielajärvi
# Närvä
# Oka
# Vättiinen
# Kaanto
# Surenheimä
# Haiste
# Sukola
# A
#
#
# Iteration: 328000, Loss: 16.536369
#
# Pivusta
# Miekaleoja
# Mäntylä
# Paigasnaahpuori
# Vuusila
# Kaakosaa
# Suuli
# Haiste
# Sihtamo
# Airta
#
#
# Iteration: 330000, Loss: 16.710592
#
# Puuturanalo
# Mule
# Nuttujuhti
# Piedapum
# Vuttan
# Laanno
# Tytila
# Haivola
# Sukkanen
# Ahtula
#
#
# Iteration: 332000, Loss: 16.673363
#
# Peturla
# Miika
# Mätöranta
# Pahahen
# Vurtamaa
# Kaalinen
# Surenimekva
# Haitsi
# Sukala
# Ahtikaari
#
#
# Iteration: 334000, Loss: 16.819475
#
# Okyväs
# Mieka
# Mötönen
# O
# Vurtakangas
# Kaappo
# Surima
# Kaitti
# Suiranen
# A
#
#
# Iteration: 336000, Loss: 16.793313
#
# Petäviitari
# Miikala-kahlila
# Möytteriines
# Paahanmma
# Vustamaa
# Kaakniema
# Suranen
# Hairo
# Ssankorkula
# Ahora
#
#
# Iteration: 338000, Loss: 16.766591
#
# Pivusi
# Miiha-ruohamäki
# Möväranta
# Paahanniemi
# Vuosala
# Kaallo
# Rytinen
# Jahto
# Ruosamo
# Ahto
#
#
# Iteration: 340000, Loss: 16.791222
#
# Pousuo
# Miekajärvi
# Nyyty
# Peiekorja
# Vursamerran
# Kaalko
# Surhi
# Haaro
# Ssarinen
# Ahtukaari
#
#
# Iteration: 342000, Loss: 16.690929
#
# Pousunen
# Mieka-sume
# Méttä
# Piedesniemi
# Vurtenimi
# Kaappo
# Turhiainen
# Jahonen
# Sukkinen
# Akoski
#
#
# Iteration: 344000, Loss: 16.908762
#
# Pivärä
# Orja
# Ottinen
# Piedanta
# Tytä
# Kaappo
# Suula
# Haarti
# Suipinen
# Ahora
#
#
# Iteration: 346000, Loss: 16.659179
#
# Mettären
# Meihakoski
# Mäsvikkala
# Mehalin
# Vurselimmanki
# Kaalonen
# Suukala
# Haista
# Ssinen
# Ahoti
#
#
# Iteration: 348000, Loss: 16.725017
#
# Pousuo
# Moijakoski
#
#
# Iteration: 380000, Loss: 16.551197
#
# Okyvuo
# Moja
# Mäsvy
# Oja
# Vurtala
# Kaallinen
# Tyvinen
# E
# Sukkanen
# Aarne
#
#
# Iteration: 382000, Loss: 16.644442
#
# Olusuo
# Mieka-päli-pänttilä
# Mötörannamarheis
# Oja
# Vuusimaa
# Kaakkola
# Suukkamaanala
# Haarpaa
# Sukkamaala
# Ahtola
#
#
# Iteration: 384000, Loss: 16.757838
#
# Piäsänen
# Miejainen
# Mäuttala
# Pahajärvi
# Vuttanen
# Kaakonen
# Vurhihinara
# Hairo
# Vulmanen
# Ahro
#
#
# Iteration: 386000, Loss: 16.970009
#
# Mettäsaelin
# Miekalainelisari
# Märvä
# Mehakoski
# Vuusila
# Kaalmä
# Susela
# Kakkula
# Ryikkö
# Ajusaainlesjo
#
#
# Iteration: 388000, Loss: 16.746542
#
# Piättä
# Pola
# Pötören
# Pahajärs
# Vustamaa
# Maakku
# Turhihen
# Kalos
# Sikkamo
# Akste
#
#
# Iteration: 390000, Loss: 16.504944
#
# Puutti
# Ola-ahtti
# Ousto
# Peiharpi
# Vurtala
# Laakko
# Turjaare
# Kahtija
# Sukkale
# Ahtti
#
#
# Iteration: 392000, Loss: 16.659362
#
# Revässala
# Prehakoski
# Pöystelkoronen
# Raha
# Vustala
# Laalosaa
# Turerensevalli
# Kaistee
# Suiranen
# Alasaa
#
#
# Iteration: 394000, Loss: 16.749839
#
# Petösnenius
# Mulha-puljalo
# Mästä-kannas
# Pahajärvi
# Tyvä-mannas
# Kaalola
# Suokkamäki
# Kaisti
# Suhlannes
# Alopaa
#
#
# Iteration: 396000, Loss: 16.771865
#
# Piätärieinen
# Niel
# Otvuoho
# Peihmää
# Väätilä
# Kaalonen
# Suuli-oravalo
# Hahtki
# Sukola
# Alasaajorvi
#
#
# Iteration: 398000, Loss: 16.523395
#
# Peuttuala
# Mela
# Nyväs
# Pahakoski
# Vuusala
# Kaakora
# Sivamaa
# Haista
# Salmenmau
# Airra
# Iteration: 400000, Loss: 16.643063
#
# Puutto
# Mule
# Märviemin
# Peidesjo
# Vustala
# Laamisaa
# Vuski
# Hakos
# Vullinieri
# Ahske
#
#
# Iteration: 402000, Loss: 16.649457
#
# Pausunen
# Opai
# Ovuora
# Pahajärse
# Vurtamaa
# Kaanto
# Turanen
# Halsta
# Tiitakkaski
# Ahri
#
#
# Iteration: 404000, Loss: 16.715031
#
# Piättä
# Ola-ahtti
# Ottonen
# Peihkonen
# Väätinen
# Maakopaa
# Tyykkylä
# Kaisti
# Tuitinen
# Ahorahi
#
#
# Iteration: 406000, Loss: 16.790271
#
# Petävieri
# Ola
# Pöyttinen
# Paahiniema
# Vustamaa
# Kaamonen
# Turinen
# I
# Tukkamäkkimäki
# Aarta
#
#
# Iteration: 408000, Loss: 16.682007
#
# Piärynen
# Moija
# Möttä
# Pehakoski
# Vuoselli
# Kaalosaalin
# Suukkamäki
# Jaitte
# Soininen
# Ajusaahkorti
#
#
# Iteration: 440000, Loss: 16.639298
#
# Miusto
# Moijaaro
# Mäyvä
# Meihinne
# Vurtamersatoki
# Kaanto
# Suummenmetkunpanganpäki
# Kaippi
# Ruipenmetkunpaokkola
# Elomejalo
#
#
# Iteration: 442000, Loss: 16.441908
#
# Niuttu
# Moka
# Möystilin
# Nieemäki
# Vustami
# Kaanro
# Supenioman
# Hairo
# Sukkanies
# Ahtti
#
#
# Iteration: 444000, Loss: 16.604457
#
# Olusto
# Neka
# Nusto
# Oha
# Vursela
# Kaakoraikko
# Supemahmara
# Haino
# Soikkolainen
# Ahtikaari
#
#
# Iteration: 446000, Loss: 16.769742
#
# Piutto
# Niema
# Nuusi
# Pehakoski
# Uutienen
# Kaaloramaa
# Susanen
# Kaistee
# Sukmanies
# Ahtokaa
#
#
# Iteration: 448000, Loss: 16.719156
#
# Olvonen
# Moaja
# Mötyluojo
# Oka
# Vustamaa
# Kaalola
# Surila
# Haista
# Ryhähti
# Alitei
#
#
# Iteration: 450000, Loss: 16.539552
#
# Peutto
# Nei
# Nutuo
# Paahaniemi
# Vurvala
# Kaalio
# Soula
# Haista
# Salmanen
# Aarmaa
#
#
# Iteration: 452000, Loss: 16.599545
#
# Niväspainen
# Miekala
# Mötäsalmi
# Nei
# Vuusinen
# Kaannija
# Suukkami
# I
# Sojakki-varppanen
# Ahtola
#
#
# Iteration: 454000, Loss: 16.659646
#
# Petävuori
# Moijakoski
# Märtölä
# Pahajärvi
# Vurtamaa
# Kaalonen
# Vuranen
# Hainola
# Uumi
# Ahri
#
#
# Iteration: 456000, Loss: 16.835735
#
# Nevurta
# Mele
# Mästä
# Ne
# Vustamaa
# Kaanroja
# Surimaa
# Kalosaanius
# Räimi
# Ahoraja
#
#
# Iteration: 458000, Loss: 16.651142
#
# Petävune
# Poijakoski
# Pötören
# Peihkonen
# Vustamaa
# Laakko
# Sureniemi
# Kaloraheiskula
# Solmanen
# Ainte
#
#
# Iteration: 460000, Loss: 16.434463
#
# Piätti
# Ola-ahtti
# Ovurta
# Peiemää
# Vuosila
# Kaanti
# Turila
# Haisti
# Sikkinen
# A
#
#
# Iteration: 462000, Loss: 16.555679
#
# Poutto
# Oma
# Oturi
# Peidensaahonen
# Uuttela
# Kaalola
# Supola
# Kaiste
# Suhkala
# Alari
#
#
# Iteration: 464000, Loss: 16.724172
#
# Olvonkari
# Meki
# Mästä
# Oja
# Tyvä
# Kaalomma
# Susanen
# Kaitti
# Sillinlatti
# Ajus
#
#
# Iteration: 466000, Loss: 16.741969
#
# Onä-tuirennesalo
# Moija
# Mötvä
# Ola
# Uutteniomasilto
# Kaappo
# Suukkala
# Haasti
# Sulkala
# Alare
#
#
# Iteration: 468000, Loss: 16.518037
#
# Poutuperoja
# Moijalin
# Märvälä
# Peiharpoija
# Vuutamersaulo
# Kaamipeija
# Tyrjämäki
# Haista
# Sulikoski
# Almo
#
#
# Iteration: 470000, Loss: 16.616440
#
# Onusuo
# Mule
# Mätys
# Oja
# Vustala
# Kaanko
# Uutala
# Haivola
# Tuitamo
# Ahtu
#
#
# Iteration: 472000, Loss: 16.607809
#
# Petätu
# Olee
# Ovurta
# Peidensa
# Väytinen
# Maakora
# Tyrjälä-jäpänkari
# Haitti
# Tukkala
# Akosela
#
#
# Iteration: 474000, Loss: 16.677243
#
# Piättä
# Orka
# Ottonen
# Paadanpekalo
# Väytinen
# Maalno-aaroll
# Surenholahti
# I
# Sukkanen
# Alonen
#
#
# Iteration: 476000, Loss: 16.669565
#
# Petäviisari
# Niejakoski
# Ovurta
# Peidari
# Vurtamaa
# Kaanore
# Sspanen
# I
# Sillankaukkomaa
# Ahtoiienterka
#
#
# Iteration: 478000, Loss: 16.580245
#
# Peusto
# Nenhamo
# Ovurta
# Peihari
# Vuosen
# Kaansue
# Supenisojärvi
# I
# Slanala
# Aksta
#
#
# Iteration: 480000, Loss: 16.630962
#
# Okuskolehto
# Nila
# Nuussali
# Oja
# Vurranen
# Kaanori
# Tyvinen
# Haaroja
# Tukola
# Ahttaa
#
#
# Iteration: 482000, Loss: 16.614273
#
# Poutti
# Omel
# Ovuoma
# Peielmo
# Vuosilä
# Kaantsa
# Tysimaa
# Haitti
# Tukkila
# Akosja
#
#
# Iteration: 484000, Loss: 16.713076
#
# Piärän
# Pola
# Pötönamaa
# Peihanta
# Uuso
# Maalko
# Suuni
# Jairne
# Sukkanen
# Ahopaa
#
#
# Iteration: 486000, Loss: 16.483305
#
# Olusuo
# Miehakoski
# Märviki
# Oja
# Värvemio
# Kaalonen
# Tyrinen
# E
# Tuirinen
# Ahtse
#
#
# Iteration: 488000, Loss: 16.638939
#
# Petävihkilehvi
# Neja
# Ousto
# Peieliska
# Vurtamaa
# Laakki
# Suselainen
# Kalno
# Suininen
# Almikaaniemi
#
#
# Iteration: 490000, Loss: 16.614438
#
# Peytys
# Ome
# Oturja
# Pehakoski
# Vustamaa
# Maakosaa
# Tyrilä
# Haisti
# Tukkanen
# Alli
#
#
# Iteration: 492000, Loss: 16.519564
#
# Orvokkala
# Ori
# Otturanta
# Oka
# Vustala
# Kaanto
# Surala
# Haitti
# Slamainasimola
# Ahrma
#
#
# Iteration: 494000, Loss: 16.552574
#
# Revästala
# Onie
# Pöyttilä
# Rahakoski
# Vustaranta
# Kaansul
# Tärjäkornies
# Kaistea
# Tuinila
# Akoska
#
#
# Iteration: 496000, Loss: 16.531606
#
# Olusmo
# Mala
# Mäustala
# Oka
# Vurrala
# Kaanrola
# Supanen
# Hakori
# Suliala
# Ahtti
#
#
# Iteration: 498000, Loss: 16.642638
#
# Poutto
# Nele
# Ovonne
# Peihapun
# Uutsala
# Maanonen
# Tyrjälä
# Haitola
# Sukkanen
# Ahtola

# %% [markdown]
# #### References:
#
#     This project took inspiration from AI SW Development Hands On workshop organized by Nokia and conducted by Tarry Singh. Implementation code uses parts of code from Andrew Ng's exercise Dinosaurus Island which is a part of Deep Learning specialization at Coursera (https://www.coursera.org/specializations/deep-learning).
