# %% [markdown]
# # Finnish Lastname Generator

# %% [markdown]
# <img src="sukunimet.jpg">

# %% [markdown]
# Have you ever wondered what would be your name or surname if you were born in another country? During last two years when I have been living in Finland this question came to my mind several times. Once I even used online generator to get myself a Finnish name and surname. Visit http://www.visitfinland.com/campaigns/finngenerator/public/en/ to check it out.
#
# However, after getting familiar with Sequential models I thought that it should be possible to use one of those to teach it to generate new surnames which would resemble already existing ones. To train such a model we would need a dataset of original Finnish lastnames. I found such at http://tuomas.salste.net/suku/nimi/index-en.html. It consists of 23,166 family names found in Finland.
#
# Let's get started!

# %%
import numpy as np
from utils import *
import random

# %% [markdown]
# ### 1 - Dataset and Preprocessing
#
# Run the following cell to read the dataset of Finnish surnames, create a list of unique characters (such as a-z), and compute the dataset and vocabulary size.

# %%
data = open('finnish_lastnames.txt', 'r', encoding='latin-1').read()
data= data.lower()
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('There are %d total characters and %d unique characters in your data.' % (data_size, vocab_size))
print('Characters are ', chars)
# Out:
# There are 153908 total characters and 29 unique characters in your data.
# Characters are  ['e', 'ä', 'p', 'k', '-', 'i', 'l', '\n', 'v', 'h', 'a', 'c', 'o', 'w', 'é', 'ö', 's', 'j', 't', 'f', 'r', 'n', 'y', 'ü', 'm', 'g', 'b', 'u', 'd']

# %% [markdown]
# The "\n" (or newline character) indicates the end of the surname rather than the end of a sentence. In the cell below, we create a python dictionary (i.e., a hash table) to map each character to an index from 0-38. We also create a second python dictionary that maps each index back to the corresponding character. This will help you figure out what index corresponds to what character in the probability distribution output of the softmax layer. Below, char_to_ix and ix_to_char are the python dictionaries.

# %%
char_to_ix = { ch:i for i,ch in enumerate(sorted(chars)) }
ix_to_char = { i:ch for i,ch in enumerate(sorted(chars)) }
print(ix_to_char)
# Out:
# {0: '\n', 1: '-', 2: 'a', 3: 'b', 4: 'c', 5: 'd', 6: 'e', 7: 'f', 8: 'g', 9: 'h', 10: 'i', 11: 'j', 12: 'k', 13: 'l', 14: 'm', 15: 'n', 16: 'o', 17: 'p', 18: 'r', 19: 's', 20: 't', 21: 'u', 22: 'v', 23: 'w', 24: 'y', 25: 'ä', 26: 'é', 27: 'ö', 28: 'ü'}

# %% [markdown]
# ### 2 - Overview of the model
#
# Your model will have the following structure:
#
# - Initialize parameters
# - Run the optimization loop
#     - Forward propagation to compute the loss function
#     - Backward propagation to compute the gradients with respect to the loss function
#     - Clip the gradients to avoid exploding gradients
#     - Using the gradients, update your parameter with the gradient descent update rule.
# - Return the learned parameters

# %% [markdown]
# We will write two helper functions. One that clips gradient values which helps to avoid exploding gradient problem. Another samples a sequence of characters according to a sequence of probability distributions output of the RNN.

# %%
def clip(gradients, maxValue):
    '''
    Clips the gradients' values between minimum and maximum.
    
    Arguments:
    gradients -- a dictionary containing the gradients "dWaa", "dWax", "dWya", "db", "dby"
    maxValue -- everything above this number is set to this number, and everything less than -maxValue is set to -maxValue
    
    Returns: 
    gradients -- a dictionary with the clipped gradients.
    '''
    
    dWaa, dWax, dWya, db, dby = gradients['dWaa'], gradients['dWax'], gradients['dWya'], gradients['db'], gradients['dby']
   
    # clip to mitigate exploding gradients, loop over [dWax, dWaa, dWya, db, dby]. (≈2 lines)
    for gradient in [dWax, dWaa, dWya, db, dby]:
        np.clip(gradient, -maxValue, maxValue, out=gradient)
    
    gradients = {"dWaa": dWaa, "dWax": dWax, "dWya": dWya, "db": db, "dby": dby}
    
    return gradients

# %%
def sample(parameters, char_to_ix, seed):
    """
    Sample a sequence of characters according to a sequence of probability distributions output of the RNN

    Arguments:
    parameters -- python dictionary containing the parameters Waa, Wax, Wya, by, and b. 
    char_to_ix -- python dictionary mapping each character to an index.
    seed -- used for grading purposes. Do not worry about it.

    Returns:
    indices -- a list of length n containing the indices of the sampled characters.
    """
    
    # Retrieve parameters and relevant shapes from "parameters" dictionary
    Waa, Wax, Wya, by, b = parameters['Waa'], parameters['Wax'], parameters['Wya'], parameters['by'], parameters['b']
    vocab_size = by.shape[0]
    n_a = Waa.shape[1]
    
    # Step 1: Create the one-hot vector x for the first character (initializing the sequence generation). (≈1 line)
    x = np.zeros(vocab_size)
    # Step 1': Initialize a_prev as zeros (≈1 line)
    a_prev = np.zeros((n_a))
    
    # Create an empty list of indices, this is the list which will contain the list of indices of the characters to generate (≈1 line)
    indices = []
    
    # Idx is a flag to detect a newline character, we initialize it to -1
    idx = -1 
    
    # Loop over time-steps t. At each time-step, sample a character from a probability distribution and append 
    # its index to "indices". We'll stop if we reach 50 characters (which should be very unlikely with a well 
    # trained model), which helps debugging and prevents entering an infinite loop. 
    counter = 0
    newline_character = char_to_ix['\n']
    
    while (idx != newline_character and counter != 50):
        
        # Step 2: Forward propagate x using the equations (1), (2) and (3)
        a = np.tanh(np.dot(Wax, x) + np.dot(Waa, a_prev) + b)
        z = np.dot(Wya, a) +  by 
        y = softmax(z)
        
        # for grading purposes
        np.random.seed(counter+seed) 
        
        # Step 3: Sample the index of a character within the vocabulary from the probability distribution y
        idx = np.random.choice(list(range(vocab_size)), p = y[:, counter].ravel())

        # Append the index to "indices"
        indices.append(idx)
        
        # Step 4: Overwrite the input character as the one corresponding to the sampled index.
        x = np.zeros((vocab_size, 1))
        x[idx] = 1
        
        # Update "a_prev" to be "a"
        a_prev = a
        
        # for grading purposes
        seed += 1
        counter +=1

    if (counter == 50):
        indices.append(char_to_ix['\n'])
    
    return indices

# %% [markdown]
# Next we will implement a function performing one step of stochastic gradient descent (with clipped gradients). You will go through the training examples one at a time, so the optimization algorithm will be stochastic gradient descent.

# %%
def optimize(X, Y, a_prev, parameters, learning_rate = 0.01):
    """
    Execute one step of the optimization to train the model.
    
    Arguments:
    X -- list of integers, where each integer is a number that maps to a character in the vocabulary.
    Y -- list of integers, exactly the same as X but shifted one index to the left.
    a_prev -- previous hidden state.
    parameters -- python dictionary containing:
                        Wax -- Weight matrix multiplying the input, numpy array of shape (n_a, n_x)
                        Waa -- Weight matrix multiplying the hidden state, numpy array of shape (n_a, n_a)
                        Wya -- Weight matrix relating the hidden-state to the output, numpy array of shape (n_y, n_a)
                        b --  Bias, numpy array of shape (n_a, 1)
                        by -- Bias relating the hidden-state to the output, numpy array of shape (n_y, 1)
    learning_rate -- learning rate for the model.
    
    Returns:
    loss -- value of the loss function (cross-entropy)
    gradients -- python dictionary containing:
                        dWax -- Gradients of input-to-hidden weights, of shape (n_a, n_x)
                        dWaa -- Gradients of hidden-to-hidden weights, of shape (n_a, n_a)
                        dWya -- Gradients of hidden-to-output weights, of shape (n_y, n_a)
                        db -- Gradients of bias vector, of shape (n_a, 1)
                        dby -- Gradients of output bias vector, of shape (n_y, 1)
    a[len(X)-1] -- the last hidden state, of shape (n_a, 1)
    """
    
    # Forward propagate through time (≈1 line)
    loss, cache = rnn_forward(X, Y, a_prev, parameters)
    
    # Backpropagate through time (≈1 line)
    gradients, a = rnn_backward(X, Y, parameters, cache)
    
    # Clip your gradients between -5 (min) and 5 (max) (≈1 line)
    gradients = clip(gradients, 5)
    
    # Update parameters (≈1 line)
    parameters = update_parameters(parameters, gradients, learning_rate)
    
    ### END CODE HERE ###
    
    return loss, gradients, a[len(X)-1]

# %% [markdown]
# ### 3 - Training the model
#
# Given the dataset of Finnish surnames, we use each line of the dataset (one surname) as one training example. Every 100 steps of stochastic gradient descent, you will sample 10 randomly chosen surnames to see how the algorithm is doing. Remember to shuffle the dataset, so that stochastic gradient descent visits the examples in random order.

# %%
def model(data, ix_to_char, char_to_ix, num_iterations = 500000, n_a = 50, surnames = 10, vocab_size = 29):
    """
    Trains the model and generates dinosaur names. 
    
    Arguments:
    data -- text corpus
    ix_to_char -- dictionary that maps the index to a character
    char_to_ix -- dictionary that maps a character to an index
    num_iterations -- number of iterations to train the model for
    n_a -- number of units of the RNN cell
    surnames -- number of Finnish surnames you want to sample at each iteration. 
    vocab_size -- number of unique characters found in the text, size of the vocabulary
    
    Returns:
    parameters -- learned parameters
    """
    
    print('n_a',n_a)
    
    # Retrieve n_x and n_y from vocab_size
    n_x, n_y = vocab_size, vocab_size
    
    # Initialize parameters
    parameters = initialize_parameters(n_a, n_x, n_y)
    
    # Initialize loss (this is required because we want to smooth our loss, don't worry about it)
    loss = get_initial_loss(vocab_size, surnames)
    
    # Build list of all dinosaur names (training examples).
    with open("finnish_lastnames.txt", encoding='latin-1') as f:
        examples = f.readlines()
    examples = [x.lower().strip() for x in examples]
    
    # Shuffle list of all dinosaur names
    np.random.seed(0)
    np.random.shuffle(examples)
    
    # Initialize the hidden state of your LSTM
    a_prev = np.zeros((n_a, 1))
    
    # Optimization loop
    for j in range(num_iterations):
        
        ### START CODE HERE ###

        # Use the hint above to define one training example (X,Y) (≈ 2 lines)
        index = j % len(examples)
        X = [None] + [char_to_ix[ch] for ch in examples[index]] 
        Y = X[1:] + [char_to_ix["\n"]]
        
        # Perform one optimization step: Forward-prop -> Backward-prop -> Clip -> Update parameters
        # Choose a learning rate of 0.01
        
        curr_loss, gradients, a_prev = optimize(X, Y, a_prev, parameters, learning_rate=0.01)
        
        ### END CODE HERE ###
        
        # Use a latency trick to keep the loss smooth. It happens here to accelerate the training.
        loss = smooth(loss, curr_loss)

        # Every 2000 Iteration, generate "n" characters thanks to sample() to check if the model is learning properly
        if j % 2000 == 0:
            
            print('Iteration: %d, Loss: %f' % (j, loss) + '\n')
            
            # The number of dinosaur names to print
            seed = 0
            for name in range(surnames):
                
                # Sample indices and print them
                sampled_indices = sample(parameters, char_to_ix, seed)
                print_sample(sampled_indices, ix_to_char)
                
                seed += 1  # To get the same result for grading purposed, increment the seed by one. 
      
            print('\n')
        
    return parameters

# %%
parameters = model(data, ix_to_char, char_to_ix)
# Out:
# n_a 50
# Iteration: 0, Loss: 33.672958
#
# Nküäävcmerpeögury-ujjiyv
# Knea
# Küäävcmerpeögury-ujjiyv
# Nea
# Üäävcmerpeögury-ujjiyv
# Ea
# Äävcmerpeögury-ujjiyv
# A
# Ävcmerpeögury-ujjiyv
#
#
#
# Iteration: 2000, Loss: 24.922524
#
# Mivuttalalo
# Kke
# Käturen
# Me
# Äturen
# E
# Utsamenkaukontaoli
#
# Uralalo
#
#
#
# Iteration: 4000, Loss: 21.670056
#
# Nevussamankaulolu
# Li
# Läsuralaineu
# Nej
# Ysuralaineu
# Ha
# Ussamankaulolu
# A
# Ttalaineu
#
#
#
# Iteration: 6000, Loss: 20.650422
#
# Omästo
# Li
# Lätuo
# Oka
# Vuusama
# Ja
# Uutala
# C-huti
# Ttala
#
#
#
# Iteration: 8000, Loss: 19.965320
#
# Olätto
# Lii
# Läutta
# Oka
# Väus
# Ka
# Uusilalkasanko
# E
# Tuinen
# Ahtti
#
#
# Iteration: 10000, Loss: 19.093830
#
# Neutto
# Liiha
# Lätto
# Nei
# Vystala
# Ja-juti
# Vusilainer
# Haitta
# Tuipami
# Ajorha
#
#
# Iteration: 12000, Loss: 18.883163
#
# Nivustalammaumontarkikora
# Leja
# Lätto
# Nei
# Vuutala
# Kaakoska
# Uusila
# Haisti
# Tukkanenoklio
# Alsta
#
#
# Iteration: 14000, Loss: 18.659883
#
# Neväry
# Leija
# Lävära
# Nei
# Ytyrgkarmes
# Kaakore
# Tyrinen
# Haiste
# Tuinen
# Aiste
#
#
# Iteration: 16000, Loss: 18.552695
#
# Olvorte
# Loija
# Lätvu
# Ola
# Västila
# Kaakos
# Värko
# Haisti
# Tuipennetalmo
# Akosi
#
#
# Iteration: 18000, Loss: 18.576495
#
# Piätynen
# Liha
# Läytykke
# Paa-juti-aksiri
# Väysinen
# Kaakosia
# Tytilahti
# Hahtti
# Tuhpali
# Ahtola
#
#
# Iteration: 20000, Loss: 18.360359
#
# Peutto
# Lehd
# Läytu
# Paa
# Ytärenikkari
# Kaakko
# Vosilaanes
# Hahtte
# Ushkallaunilu
# Ahtsa
#
#
# Iteration: 22000, Loss: 17.996901
#
# Olvospajalheumo
# Liiiajongaalo
# Läytä
# Pehajäri
# Väyrila
# Kaajoseha
# Värila
# Haitse
# Uulihonetko
# Ahtokaanteri
#
#
# Iteration: 24000, Loss: 18.288956
#
# Poytäri
# Loja
# Löytä
# Pehajäri
# Yuutala
# Kaakosa
# Vätilemi
# Hakosaa
# Vähvinen
# Aloneka
#
#
# Iteration: 26000, Loss: 18.034035
#
# Piötunaki
# Liiha
# Läätä
# Pehahuri
# Vuttala
# Kaajore
# Tyyjä-pokulinta
# Hahto
# Tuirho
# Ahtti
#
#
# Iteration: 28000, Loss: 17.955205
#
# Miutto
# Kila
# Kävänen
# Maa
# Vuttala
# Kaaknoja
# Turimaa
# Hakopa
# Tukkanen
# Almoka
#
#
# Iteration: 30000, Loss: 17.871108
#
# Pettoo
# Miei
# Mättä
# Paaakosa
# Vuurenen
# Kaakosa
# Tusamaa
# Hairpe
# Tulkangas
# Aarti
#
#
# Iteration: 32000, Loss: 17.957525
#
# Onutto
# Liiha
# Läutsala
# Ola
# Vuttala
# Kaakosa
# Tyykkkälerjyrä
# Aaarieka
# Tuki-liivanio
# Aissa
#
#
# Iteration: 34000, Loss: 17.794103
#
# Onusto
# Leha
# Märvibmarsatimokari
# Oka
# Vuusala
# Kaakstaaho
# Tuulajorinen
# Haissaaaro
# Tokilaahti
# Aissa-heskola
#
#
# Iteration: 36000, Loss: 17.897210
#
# Meutto
# Kone
# Käyvä
# Meha
# Väytiieni
# Kaakko
# Tusamaa
# Hahto-aamokokki
# Toisila
# Aitte
#
#
# Iteration: 38000, Loss: 17.685255
#
# Mettunen
# Lehea
# Läutsala
# Maihaniema
# Vuusimaa
# Jaakosaa
# Tusinen
# Haistaa
# Toinao
# Ajori
#
#
# Iteration: 40000, Loss: 17.578337
#
# Meutto
# Kela
# Läättiaanietmuomaa
# Neeenose
# Vuttala
# Jaajonen
# Tusala
# Haitte
# Toimanietila
# Ajuri
#
#
# Iteration: 42000, Loss: 17.858486
#
# Petuso
# Liha
# Mäsäri
# Pehaampi
# Vuttala
# Jaakosa
# Tusala
# Hahosa
# Tsila
# Aissa
#
#
# Iteration: 44000, Loss: 17.601796
#
# Pevärpala
# Muka
# Möytyjäki
# Paadasta
# Väytilio
# Kaalisaahaniomaasa
# Tyykkilä
# Hahtsa
# Tukilio
# Alitaaharinen
#
#
# Iteration: 46000, Loss: 17.694136
#
# Metture
# Kolha-riijalo
# Lyyty
# Madalipeehjulu
# Vuttala
# Kaakko
# Tusjakki
# Haista
# Tokkenies
# Ajorha
#
#
# Iteration: 48000, Loss: 17.587871
#
# Peutttenili
# Leijainiema
# Mästy-parojälvi
# Pehainpa
# Vuusila
# Kaakkuiehojala
# Tyykkinen
# Haivula
# Tukkanies
# Ahtti
#
#
# Iteration: 50000, Loss: 17.591500
#
# Peusto
# Niika-sunekkälä
# Pävängakki
# Peha
# Väsä-karlaupias
# Kaakonen
# Tuukkala
# Haiste
# Tulkeli
# Aista
#
#
# Iteration: 52000, Loss: 17.625355
#
# Piätynen
# Muki
# Mästä
# Pehakoski
# Vuttala
# Kaalonen
# Tutimaaakunen
# Haitti
# Tukkanen
# Alopi
#
#
# Iteration: 54000, Loss: 17.711432
#
# Nivusraja
# Liiha-pynhaly
# Mästä
# Nek
# Väysilä
# Kaalmuka
# Turkkell
# Haisula
# Tummenkati
# Ajome
#
#
# Iteration: 56000, Loss: 17.442883
#
# Onusonen
# Muma
# Mäussala
# Oka
# Väärinen
# Kaallo
# Tusilainen
# Haista
# Tullanhas
# Almo
#
#
# Iteration: 58000, Loss: 17.454564
#
# Pevärvi
# Meke
# Märys
# Paha-rike
# Vuttala
# Kaakko
# Tuulihmi
# Haista
# Tullanieti
# Aitte
#
#
# Iteration: 60000, Loss: 17.505199
#
# Piätönen
# Miikakoska
# Möyväkkinen
# Peiemää
# Vutsala
# Kaaknola
# Utsala
# Haista
# Tukkala
# Alore
#
#
# Iteration: 62000, Loss: 17.310555
#
# Olvori
# Kildajuuma
# Läytä
# Oja
# Vuttala
# Kaakko
# Tutala
# Hahtte
# Tokkanenen
# Aista
#
#
# Iteration: 64000, Loss: 17.421484
#
# Nevtpu
# Moka
# Mätäpen
# Neederve
# Vätula
# Kaakko
# Turjojokinen
# Hahro
# Tulimoe
# Almoekanneri
#
#
# Iteration: 66000, Loss: 17.307990
#
# Revussala
# Nieha
# Näästimikkati
# Rahajärvi
# Vuttala
# Kaajsu
# Tyykkinen
# Halosaahi
# Tullankaukkonaniemi
# Almoja
#
#
# Iteration: 68000, Loss: 17.498912
#
# Pevärta
# Ongaaho
# Pöyty
# Pehaasti
# Vävä-oippaunini
# Kaakko
# Tytilahterinen
# Iahopaa
# Tukkanen
# Almoja
#
#
# Iteration: 70000, Loss: 17.487794
#
# Pevärä
# Mieja
# Mäpärakilj
# Paaalline
# Väväjä
# Kaaknte
# Tyykikorinen
# I
# Tukkanen
# Aista
#
#
# Iteration: 72000, Loss: 17.633722
#
# Pevusoija
# Miekajärti
# Mätönen
# Paadaspaa
# Vuusala
# Kaakkula
# Tyylsinen
# Haitti
# Tukkanen
# Aippa
#
#
# Iteration: 74000, Loss: 17.397873
#
# Pevärvenen
# Mika
# Mösäranniemu
# Pehajäro
# Vävä
# Kaakori
# Tyylä
# Haitti
# Tulmenkaumi
# Ajonen
#
#
# Iteration: 76000, Loss: 17.559669
#
# Peutto
# Leija
# Lääsä
# Paahansi
# Vääsilä
# Kaakko
# Turja
# Haista
# Tukkala
# Alko
#
#
# Iteration: 78000, Loss: 17.360478
#
# Peusto
# Miika-tune
# Näysvinen
# Paaharti
# Väätinen
# Kaakkula
# Tusila
# Hahtoja
# Tukkanki-kostanen
# Ahso
#
#
# Iteration: 80000, Loss: 17.356048
#
# Piäturi
# Lohe
# Mätäri
# Pehajärma
# Vuotama
# Kaalopa
# Turimaa
# Hakora
# Tullanen
# Alonen
#
#
# Iteration: 82000, Loss: 17.254204
#
# Piättsainen
# Miihakoske
# Mäsäranen
# Pahalahpe
# Väysimaki
# Kaderva
# Tyveniokasalo
# Haitti
# Tukila
# Almo
#
#
# Iteration: 84000, Loss: 17.191055
#
# Peutto
# Moijalainen
# Möyttila
# Paaalo
# Vätäkkinen
# Kaalko
# Turimaa
# Hahtola
# Tukkenkato
# Alovaa
#
#
# Iteration: 86000, Loss: 17.214521
#
# Peutto
# Muka
# Nävärenankaski
# Raihanka
# Vuurenala
# Kaalisaa
# Tyukkala
# Haisti
# Tukijärpä
# Aisola
#
#
# Iteration: 88000, Loss: 17.553254
#
# Rivusti
# Poija
# Päätä
# Rahahto
# Vääsimaa
# Kaamonen
# Tusimaa
# Haisti
# Tukkamo
# Alopa
#
#
# Iteration: 90000, Loss: 17.285725
#
# Piättä
# Msiiaaro
# Mätörala
# Pahajärvi
# Vustala
# Kaakosaa
# Tytila
# Haisti
# Tuinela
# Alitia
#
#
# Iteration: 92000, Loss: 17.008500
#
# Peväri
# Meke
# Märvä
# Paadenpehelvonen
# Tuusa-herjäjärvi
# Kaalosaaho
# Susalahtinen
# Hahtsi
# Slaninen
# Almpa
#
#
# Iteration: 94000, Loss: 17.256031
#
# Piästi
# Msihala
# Mätyri
# Peidesli
# Väärio
# Kaakori
# Sutanen
# Hakori
# Sulkinies
# Alesi
#
#
# Iteration: 96000, Loss: 17.297062
#
# Piättuinen
# Niek
# Outto-nikoluoro
# Pehakoski
# Vyyrinen
# Kaalonen
# Syykkinen
# Hahtola
# Suirinieti
# Aitti
#
#
# Iteration: 98000, Loss: 17.198600
#
# Pevärä
# Laha
# Mävärila
# Paahanoja
# Vytä-karketinen
# Kaakko
# Tyvänen
# Hahspa
# Tukkala
# Alori
#
#
# Iteration: 100000, Loss: 17.254232
#
# Revopunnaskaski
# Njokakoski
# Oussi
# Raha
# Uuslahemtarento
# Kaalkola
# Suranen
# Jaasti
# Soinanen
# Akoshe
#
#
# Iteration: 102000, Loss: 17.136732
#
# Riättä
# Oni
# Pääsä
# Rehaappa
# Vuurho
# Kaakmu
# Tuukkanen
# Hahopi
# Tullenmaliniuko
# Ajore
#
#
# Iteration: 104000, Loss: 17.318901
#
# Reuttsala
# Poijaanta
# Röyttila
# Rahahtu
# Väätila
# Laakko
# Tyykkinen
# Haitta
# Tulmanen
# Allti
#
#
# Iteration: 106000, Loss: 17.286370
#
# Revppo
# Peijainen
# Päätä
# Rahakoske
# Vuttanen
# Kaalnoka
# Tusanen
# Jaitta-alrio
# Toinanen
# Aitta
#
#
# Iteration: 108000, Loss: 17.021128
#
# Reväsoinen
# Piikalis
# Pääsycninojäki
# Rahajärre
# Vustamaan
# Kaanssaaari
# Turinen
# Iajore
# Tukkari
# Allo
#
#
# Iteration: 110000, Loss: 16.999757
#
# Petäsnen
# Niekajärvi
# Outtpeo
# Paadastke
# Työtkä
# Kaakopa
# Susinen
# Jagsoja
# Siinionen
# Elosi
#
#
# Iteration: 112000, Loss: 17.363692
#
# Rivori
# Piekakoski
# Päätvila
# Riehinpei
# Vuoranen
# Kaakori
# Turila
# Haettie
# Tummalietingo
# Alisie
#
#
# Iteration: 114000, Loss: 17.085822
#
# Revoskala
# Pihd
# Päätä
# Raadisti
# Vuusinen
# Kaappo
# Suuiniomaumikoari
# Iakopaa
# Sullenmau
# Alonen
#
#
# Iteration: 116000, Loss: 17.147216
#
# Reutto
# Onga
# Päätä
# Raaharu
# Vätäjäinen
# Kaakko
# Turkkala
# Haaste
# Sulnen-etonen
# Allo
#
#
# Iteration: 118000, Loss: 16.983135
#
# Piätty
# Lehi
# Läätykorpiisan
# Paaherla
# Vuttanen
# Kaakosela
# Tyykkäällö
# Haesti
# Tullanen
# Alori
#
#
# Iteration: 120000, Loss: 17.038106
#
# Pivppuho
# Noka
# Outto
# Peidenpei
# Väytio
# Kaalko
# Tyykkinen
# Haiste
# Sulkenlaski
# Alnoka
#
#
# Iteration: 122000, Loss: 17.050892
#
# Rivussalhi
# Noka
# Näästirinnen
# Raadarun
# Vyväkorpi
# Kaakori
# Vurkka
# Haitti
# Tukkala
# Alnpa
#
#
# Iteration: 124000, Loss: 17.287533
#
# Piätureinen
# Liihakoski
# Mätören
# Peidanne
# Vuusala
# Kaalosaa
# Tyvenilmi
# Haisti
# Tulmenmati
# Ahonen
#
#
# Iteration: 126000, Loss: 17.014156
#
# Miätunen
# Kolda
# Käävä
# Maaharo
# Väätila
# Haamlo
# Surjaala
# Haivoka
# Sukkanen
# Almo
#
#
# Iteration: 128000, Loss: 17.218044
#
# Sivossala
# Reijajärka
# Rääsä-rantaverpä
# Saahesto
# Väyrilahti
# Kaakko
# Tyyki
# Hahsokainen
# Tullasmari
# Allila
#
#
# Iteration: 130000, Loss: 17.157325
#
# Petäsla
# Meki
# Mättä
# Paahanne
# Väväkka
# Kaalosaahi
# Turila
# Haasti
# Tujala
# Alluja
#
#
# Iteration: 132000, Loss: 17.049319
#
# Revärti
# Niekahto
# Outti
# Raidenti
# Uusranen
# Kaakkoka
# Tyykkinen
# Haisti
# Soinenietimuuhi
# Alonen
#
#
# Iteration: 134000, Loss: 17.072364
#
# Reväsnen
# Meki
# Määstii
# Raaharra
# Tuusio
# Kaakko
# Turhikos
# Hahopa
# Tulkjäiniemi
# Alkoja
# Iteration: 136000, Loss: 17.004848
#
# Riutto
# Noka
# Outtmaa
# Reha
# Väytsu
# Kaakonen
# Tyykki
# Hahtte
# Tukkala
# Akosaa
#
#
# Iteration: 138000, Loss: 17.565406
#
# Peuttia
# Nieh
# Outto
# Paagaro
# Vursimaa
# Kaajonen
# Tyrjä
# Haitti
# Tukkala
# Alari
#
#
# Iteration: 140000, Loss: 17.414495
#
# Peuttman
# Lihhahola
# Läytäho
# Paaharla
# Vuusila
# Haakko
# Tuukkala
# Hahtti
# Tujakka
# Alsta
#
#
# Iteration: 142000, Loss: 17.174514
#
# Revori
# Niek
# Nyyttill
# Raadasti
# Vutsala
# Kaalisaa
# Vuolajärvu
# Haitse
# Tulijärvi
# Aitra
#
#
# Iteration: 144000, Loss: 16.704940
#
# Rautto
# Ntai
# Outto-nilmesanon
# Rahajärsa
# Väätis
# Kaalonen
# Tuukkanen
# Haitti
# Tulkimo
# Alkola
#
#
# Iteration: 146000, Loss: 17.164730
#
# Peusto
# Meijajärvi
# Märvä
# Paadanniekininen
# Vuttala
# Kaaljoikannes
# Tyykkonen
# Haasti
# Tukkala
# Ahtoka
#
#
# Iteration: 148000, Loss: 16.950133
#
# Rivppo
# Ori
# Päätä
# Rehakoski
# Vurtamaa
# Kaakori
# Täykomäki
# Haaste
# Tykkynen
# Eksve
#
#
# Iteration: 150000, Loss: 17.017550
#
# Pevsäla
# Miel-jäske
# Mättä
# Pehakoski
# Väusala
# Kaalio
# Tyykkilä
# Haitta
# Ttelala
# Aleti
#
#
# Iteration: 152000, Loss: 16.962657
#
# Petustainen
# Maikakosjo
# Märvä
# Paahesti
# Vytykongantainen
# Kaakko
# Tyvimaa
# Halosaa
# Stenirkas
# Almoja
#
#
# Iteration: 154000, Loss: 16.899860
#
# Rauttu
# Pela
# Pääsä
# Raehankaahalahi
# Vurpala
# Kaalori
# Tuukkala
# Hahtti
# Summala
# Alopaa
#
#
# Iteration: 156000, Loss: 16.946509
#
# Rhätönen
# Niekainie
# Ousto
# Raha
# Väusala
# Kaamppa
# Tyvimo
# Hahto
# Tukkanen
# Alko
#
#
# Iteration: 158000, Loss: 17.053533
#
# Rivspo
# Piek
# Päättikankaski
# Reiherun
# Väytimaa
# Kaamori
# Turji
# Haivola
# Tummenieti
# Allo
#
#
# Iteration: 160000, Loss: 16.763589
#
# Piäturanti
# Niel
# Outio
# Peidaro
# Vustamaa
# Kaanora
# Tyvikari
# Haitula
# Tunnenjatannkangarpi
# Allo
#
#
# Iteration: 162000, Loss: 16.843839
#
# Seväsoinen
# Rhi
# Ryöty
# Saaharsa
# Vuotamaa
# Laakoraa
# Tutamaemi
# Haasta
# Ttipinen
# Aitta-alojäi
#
#
# Raahasti
# Vistilaalalahti
# Kaalko
# Tysikangas
# Haatti
# Ttimenieti
# Ahto
#
#
# Iteration: 196000, Loss: 16.722803
#
# Revppi
# Mula
# Mätty
# Raahasto
# Väväho
# Kaallo
# Tvikkanen
# Haasti
# Tulkanen
# Elori
#
#
# Iteration: 198000, Loss: 17.106419
#
# Rivusti
# Piek
# Rääty
# Reielus
# Väätinen
# Kaakoo
# Tuuki-soivero
# Hakooka
# Tukkamo
# Allpo
#
#
# Iteration: 200000, Loss: 16.868132
#
# Reutto
# Miela
# Nääty
# Raha
# Vuotila
# Kaalipaahoinen
# Turjo
# Hahto
# Tuhtemo
# Aitti
#
#
# Iteration: 202000, Loss: 16.856530
#
# Pettonen
# Muka
# Nyösä
# Paahanpie
# Vättimaa
# Kaakko
# Tuo
# Haippa
# Toinentamo
# Almoja
#
#
# Iteration: 204000, Loss: 16.759904
#
# Pivustela
# Moikainen
# Mäsvä
# Pehakoski
# Väärila
# Kaamonen
# Suren
# Haaro
# Suinenmari
# Aisti
#
#
# Iteration: 206000, Loss: 16.795410
#
# Revori
# Niek
# Outto
# Raaharmaa
# Vuorenen
# Kaanonen
# Tyykkylä
# Hahrkaa
# Tulkanen
# Ahtoja
#
#
# Iteration: 208000, Loss: 16.827926
#
# Revorkangases
# Niikajärve
# Nyvärho
# Raaharsa
# Vustamaa
# Kaalisela
# Suula-onitinjä
# Hahtola
# Sokikka
# Aissa-hesmo
#
#
# Iteration: 210000, Loss: 16.933143
#
# Meutti
# Konda
# Käytä
# Mahajärvi
# Vääski
# Kaaklo
# Tyyknikkamaa
# Hahtoja
# Sulmanen
# Ahri
#
#
# Iteration: 212000, Loss: 16.789963
#
# Peutsola
# Miek
# Mäutola
# Peidanne
# Vousinen
# Kaalipaa
# Turimaa
# Haistia
# Toinenkaunnirala
# Allola
#
#
# Iteration: 214000, Loss: 16.713812
#
# Peutto
# Meki
# Möyty
# Paahanta
# Vuusala
# Jaakonen
# Tyykkilä
# Haasti
# Tula-mektinen
# Ajonen
#
#
# Iteration: 216000, Loss: 16.939477
#
# Riutti
# Nihe
# Outtiaho
# Rahajärvi
# Vuskala
# Haakonen
# Turhijärpä
# Hahrkka
# Tuhkamäki
# Elonen
#
#
# Iteration: 218000, Loss: 16.938903
#
# Rautto
# Piekalio
# Pöytäinen
# Rahajärvi
# Vurtala
# Kaalkpe
# Tyykula
# Haitte
# Tulkanen
# Aljula
#
#
# Iteration: 220000, Loss: 16.932695
#
# Nivusnen
# Miela
# Möysä
# Neidasta
# Vottala
# Kaalmunen
# Tusila
# Haaste
# Tokkenlammi
# Aitte
#
#
# Iteration: 222000, Loss: 16.822051
#
# Peuttu
# Nihdaappa
# Ousto
# Paaherve
# Vutten
# Kaalinen
# Tyykkinen
# Haisti
# Tylminietinen
# Ahtti
#
#
# Iteration: 224000, Loss: 16.657672
#
# Riutunen
# Pihi
# Päätä
# Reidarka
# Väytilehto
# Kaakkula
# Suukkala
# Hahonen
# Sumi
# Alkoka
#
#
# Iteration: 226000, Loss: 16.869908
#
# Riutto
# Pihhakoski
# Päättimäki
# Reidenoja
# Vätäkorvi
# Laakonen
# Turila
# Hahttia
# Tukkamäki
# Derula
#
#
# Iteration: 228000, Loss: 16.973846
#
# Nivustela
# Mrel
# Mästy
# Neieläki
# Uussala
# Haamusaainiepaarvi
# Syvilinenne
# Hahtsi
# Summenieti
# Almpa
#
#
# Iteration: 230000, Loss: 16.759488
#
# Piättua
# Muojajuto
# Määttimaa
# Pehalin
# Väärinen
# Kaappo
# Turhiinen
# Hakosaahko
# Tumpinen
# Almo
#
#
# Iteration: 232000, Loss: 16.777743
#
# Revppi
# Niekajärvi
# Nyyty
# Raielsäinen
# Uuttala
# Kaakku
# Tyvimaa
# Hahtti
# Tulkanieti
# Aitti
#
#
# Iteration: 234000, Loss: 16.879967
#
# Rlvpunen
# Onha
# Pöytäkiemi
# Rahakko
# Vussala
# Jaakko
# Tyykkylä
# Haippo
# Tylkkälysimo
# Alsti
#
#
# Iteration: 236000, Loss: 16.708322
#
# Nivosta
# Kkijajärve
# Lästi
# Niedeola
# Vustala
# Kaamisaa
# Tuujaala
# Haastea
# Tukkala
# Alova
#
#
# Iteration: 238000, Loss: 16.857344
#
# Pevästa
# Miek
# Määttikari
# Paahasti
# Väärenen
# Kaalipaa
# Tyykkilä
# Haastea
# Tulikke
# Alesja
#
#
# Iteration: 240000, Loss: 16.734968
#
# Rautto
# Peki
# Pöyty
# Rahajärvi
# Väytkä
# Kaaliska
# Tyykkinen
# Hakori
# Tulkankaunnita
# Alnoka
#
#
# Iteration: 242000, Loss: 16.754416
#
# Pettppajaki
# Niha
# Otvonen
# Pehakosi
# Vätvisalo
# Kaalipaaingas
# Susikangas
# Hahtokaari
# Stemamo
# Allo
#
#
# Iteration: 244000, Loss: 16.896648
#
# Reutto
# Oja
# Pääty
# Raahdoja
# Vätykomo
# Kaamora
# Tusanen
# Haisti
# Tukila
# Aitte
#
#
# Iteration: 246000, Loss: 17.003654
#
# Peutto
# Mielahonen
# Mätörinen
# Paahanoja
# Vustanalo
# Kaalkula
# Suuli
# Hahtka
# Soinenmerijärinen
# Aistee
#
#
# Iteration: 248000, Loss: 16.733640
#
# Peutto
# Niikajärvi
# Nyytti
# Paahari
# Vyäti
# Kaalio
# Tyylminen
# Hahtola
# Tulmanen
# Almola
#
#
# Iteration: 250000, Loss: 16.852501
#
# Reväspali
# Niiha
# Näysä
# Raha
# Väyskä
# Kaakko
# Tuthe
# Haasta
# Tulkela
# Alinen
#
#
# Iteration: 252000, Loss: 16.801308
#
# Peutto
# Moka
# Näyttilä
# Paahasteihonkki
# Väärinen
# Kaakku
# Tuokkinen
# Haarsi
# Tukkinen
# Ahtsi
#
#
# Iteration: 254000, Loss: 16.751013
#
# Onutti
# Mola
# Mäytäjärvi
# Oja
# Vuosila
# Kaaltula
# Turkkila
# Hakori
# Sulmennhy
# Alonen
#
#
# Iteration: 256000, Loss: 16.711839
#
# Mettäranniempi
# Rieherun
# Vuoranen
# Kaalio
# Turilahti
# Haatti
# Tuomari
# Allo
#
#
# Iteration: 288000, Loss: 16.474638
#
# Rivonkangas
# Oni-aisti
# Päätä-lannetio
# Raaharma
# Vytäjäki
# Kaappo
# Tusilaaminen
# Haasti
# Stenistin
# Almo
#
#
# Iteration: 290000, Loss: 16.733563
#
# Reutto
# Mela
# Näyvähi
# Raahangaa
# Vätä
# Kaallo
# Turkkenen
# Hahtti
# Tokkala
# Almo
#
#
# Iteration: 292000, Loss: 16.570362
#
# Rautto
# Niekajärvi
# Ottso
# Raahinki
# Väätsäläimäki
# Kaa-sunediverki
# Uus
# Hairsa
# Tti
# Aisti
#
#
# Iteration: 294000, Loss: 16.603522
#
# Peuttla
# Miekainoja
# Näväri
# Peihanpeijyrinen
# Väsä-larpeukkala
# Kaalio
# Tvokiala
# Hairre
# Sulikka
# Akori
#
#
# Iteration: 296000, Loss: 16.583766
#
# Riutto
# Njoiakrti
# Nyyväinen
# Raaharti
# Vurtamaa
# Kaakoo
# Vuokkala
# Haarti
# Voipiniepinis
# Allo
#
#
# Iteration: 298000, Loss: 16.859946
#
# Reväniemi
# Niek
# Nyyväkka
# Raiakoski
# Vuusikintari
# Kaamonen
# Tyrjälä
# Haiste
# Tulkanies
# Ahso
#
#
# Iteration: 300000, Loss: 16.635007
#
# Mettunen
# Keii
# Käävä-karmasalo
# Maaharma
# Väätinen
# Haamio
# Sutamaa
# Aaloraahio
# Soirankaunhel
# Alasaainen
#
#
# Iteration: 302000, Loss: 16.762499
#
# Rauttoamaa
# Peki
# Pääsä
# Raahevuoja
# Väusinen
# Laakorha
# Turanen
# Hahtti
# Tulkanietala
# Allina
#
#
# Iteration: 304000, Loss: 16.701765
#
# Nivusta
# Moijakusela
# Mättä
# Neienopela
# Väsäjäinen
# Kaalmuna
# Tuokkenieri
# Haasula
# Soinela
# Alosaa
#
#
# Iteration: 306000, Loss: 16.628324
#
# Reutto
# Meki
# Nyötä
# Rehakoski
# Väätikerpisenne
# Kaanorakannas
# Turkkame
# Hairs
# Soininen
# Aisti
#
#
# Iteration: 308000, Loss: 16.663077
#
# Reutto
# Meihakoski
# Määtukka
# Rahajoki
# Väätjäinen
# Jaakko
# Turhikka
# Hahtoja
# Tulhanen
# Airo
#
#
# Iteration: 310000, Loss: 16.571398
#
# Riutto
# Moijahto
# Möytäjäinen
# Rehajärvi
# Vääti
# Kaalonen
# Turila
# Haisti
# Tullakka
# Aiste
#
#
# Iteration: 312000, Loss: 16.781100
#
# Riytäri
# Niei-krula
# Näväri
# Raha-sula
# Vätykorpi
# Kaakopela
# Tuperantatoinen
# Haitti
# Ttimanen
# Allii
#
#
# Iteration: 314000, Loss: 16.948653
#
# Mauvonen
# Heihajuupa
# Jätyri
# Mahalin
# Vätöjä
# Haaliraimaa
# Tutila
# Haivola
# Sukkanen
# Alsti
#
#
# Iteration: 316000, Loss: 16.761106
#
# Peturi
# Mundaalo
# Mäytäjärvi
# Peiemälä
# Väätinen
# Kaalirha
# Vätimurs
# Hahtola
# Tulkanieo
# Alio
#
#
# Iteration: 318000, Loss: 16.438463
#
# Peturi
# Nola
# Nyytula
# Paahari
# Vääsinen
# Laakonen
# Tuuli
# Hajonen
# Tulkenmiunnita
# Almola
#
#
# Iteration: 320000, Loss: 16.959452
#
# Peuttoheisi
# Miek
# Määsäinen
# Paaharti
# Vätäjäkko
# Kaalinen
# Turkkamo
# Haasta
# Suinenmakajärjä
# Ahrila
#
#
# Iteration: 322000, Loss: 16.626239
#
# Reutto
# Onia
# Pöätö
# Reidanla
# Vuoren
# Kaalmen
# Tyykkinies
# Haarte
# Tuine
# Aloti
#
#
# Iteration: 324000, Loss: 16.699019
#
# Nivopo
# Muoka
# Möytäjäinen
# Niehanne
# Väsvenen
# Kaalio
# Syvilainen
# Hagro
# Sokiallio
# Alloka-mäksy
#
#
# Iteration: 326000, Loss: 16.696345
#
# Niutto
# Maihakoski
# Märynen
# Neifkosaaakunnel
# Vuorenalo
# Kaalro
# Suojakoski
# Hahtsi
# Sokkenies
# Almo
#
#
# Iteration: 328000, Loss: 16.692949
#
# Reväpuro
# Poka
# Pöyttela
# Raahaniemi
# Vursala
# Kaalloka
# Tuukkala
# Hahutaa
# Sulmanen
# Akori
#
#
# Iteration: 330000, Loss: 16.655248
#
# Reutto
# Onja
# Pätäreinen
# Raaharkka
# Vätti
# Kaalipeki
# Tyylä-rihvanija
# Hahto
# Tukkanies
# Allo
#
#
# Iteration: 332000, Loss: 16.792860
#
# Rivppo
# Niel
# Otvonen
# Reihanoja
# Väytiä
# Kaaliska
# Turkkala
# Halste
# Tulmenkaskkii
# Almo
#
#
# Iteration: 334000, Loss: 16.585497
#
# Reutto
# Niel
# Nyytä
# Raha
# Vustanen
# Kaaponen
# Tyvelin
# Hakotaa
# Tuno
# Alotaa
#
#
# Iteration: 336000, Loss: 16.549373
#
# Rettäpai
# Onha
# Päästela
# Raaharo
# Vätäho
# Kaakopaa
# Turenhki
# Haasta
# Sohkanen
# Aistea
#
#
# Iteration: 338000, Loss: 16.784888
#
# Pauttmakinnas
# Nola
# Näätykonnaasalo
# Paahasti
# Vuuramaa
# Kaakonen
# Soreniemi
# Haiste
# Sierennas
# Aittia
#
#
# Iteration: 340000, Loss: 16.476948
#
# Petärva
# Melha
# Näätä
# Pahajärvi
# Vuorala
# Kaanonen
# Turi
# Haippi
# Sulkemo
# Almo
#
#
# Iteration: 342000, Loss: 16.661641
#
# Niutto
# Liiha
# Lätyri
# Neigasti
# Väsä
# Kaalio
# Tysikangas
# Hahri
# Sylminen
# Airpi
#
#
# Iteration: 344000, Loss: 16.559077
#
# Ontusi
# Lehe
# Lätymaa
# Ola
# Värula
# Jeelonen
# Sutelahtihilis
# Halmoja
# Sulkkulamo
# Allo
#
#
# Iteration: 346000, Loss: 16.612340
#
# Onutto
# Miekalahti
# Mästö
# Okhakoski
# Västila
# Kaakonen
# Tytinen
# Haistee
# Sokkanen
# Almola
#
#
# Kaappre
# Sureniemi
# Haarre
# Suimenkasillo
# Allikaari
#
#
# Iteration: 380000, Loss: 16.609474
#
# Petttu
# Niekaarma
# Näättillo
# Paahasla
# Väätisalo
# Kaapppa
# Tyre
# A
# Sulmanen
# Ahri
#
#
# Iteration: 382000, Loss: 16.678981
#
# Pettto
# Mele
# Nyytälä
# Peihanmaa
# Vursenen
# Kaalisela
# Suukkamo
# Hahsola
# Sollanen
# Almikaapolma
#
#
# Iteration: 384000, Loss: 16.806574
#
# Meutti
# Konaajärvi
# Läkoski
# Maahanne
# Vääskkilä
# Kaappä
# Tupanen
# Hahto
# Suljanen
# Ainen
#
#
# Iteration: 386000, Loss: 16.618831
#
# Niöyrä
# Mela
# Märönen
# Neidari
# Vursala
# Jaalipaa
# Turkikoris
# Haisti
# Toikinen
# Almi
#
#
# Iteration: 388000, Loss: 16.493090
#
# Nevässalki
# Meki
# Määstila
# Nehakoski
# Vuspala
# Haakora
# Turjo
# Hahrika
# Ttinhonen
# Aisniahala
#
#
# Iteration: 390000, Loss: 16.764713
#
# Petäso
# Mihda
# Määrä
# Pehakoski
# Vuslala
# Haakos
# Tuoli
# Hahri
# Soilaskasimo
# Akosa
#
#
# Iteration: 392000, Loss: 16.554606
#
# Revustainen
# Niiha
# Otttu
# Rahajärvi
# Vuutala
# Jaalmoi
# Tyykkikmas
# Haasti
# Sterenmata
# Alipia
#
#
# Iteration: 394000, Loss: 16.713810
#
# Niutto
# Mekha
# Märynen
# Neiennuo
# Vuorikius
# Kaalpula
# Ttokkala
# Haarta
# Tierila
# Airta
#
#
# Iteration: 396000, Loss: 16.633691
#
# Peturo
# Mela
# Mästö
# Pejakko
# Värveniis
# Jaakkula
# Tyvanen
# Hahtti
# Tulelkokulmi
# Ahtti
#
#
# Iteration: 398000, Loss: 16.499220
#
# Riutto
# Niii
# Outto
# Reiderve
# Väsäinen
# Kaakonen
# Suukkala
# Hairo
# Sullenlammi
# Akori
#
#
# Iteration: 400000, Loss: 16.621235
#
# Pettunainen
# Mieiahoki
# Mättä
# Peidanoja
# Väsäjännen
# Kaallo
# Turkkanen
# Hahtti
# Sullamäki
# Alioja
#
#
# Iteration: 402000, Loss: 16.704850
#
# Meuvomaa
# Leijaalo
# Lyäty
# Maahemäki
# Väsä-leppisalo
# Haamus
# Surela
# Haiste
# Summala
# Almpa
#
#
# Iteration: 404000, Loss: 16.583409
#
# Nivosaari
# Miekalemi
# Määtäjäki
# Neihasniemi
# Väärinen
# Iehionen
# Suranen
# Aansala
# Sulkari
# Allija
#
#
# Iteration: 406000, Loss: 16.590482
#
# Olvoonen
# Niik
# Nyytäkelto
# Oja
# Väärenen
# Kaaknoja
# Tyykninen
# Hahtola
# Soininen
# Alopa
# Iteration: 408000, Loss: 16.674006
#
# Piätönen
# Niihajus
# Näätäkiinen
# Pelakoski
# Vursila
# Haakonen
# Tyäkkilä
# Halppi
# Tulkenkasen
# Alonen
#
#
# Iteration: 410000, Loss: 16.382107
#
# Nivosla
#
#
# Iteration: 442000, Loss: 16.714232
#
# Niustojulimmäki
# Kore
# Läsynen
# Neidero
# Väsälä
# Haakori
# Sutanen
# Hakooja
# Stiminiemi
# Allohaari
#
#
# Iteration: 444000, Loss: 16.665368
#
# Niutunen
# Munkakoski
# Mätänen
# Nieherti
# Vuorgannietinin
# Jaalonen
# Tyykkonieri
# Haippo
# Sullenmas
# Alonen
#
#
# Iteration: 446000, Loss: 16.605081
#
# Niytäri
# Meladanta
# Mätyri
# Neienooka
# Vuro
# Jaajori
# Tuokkala
# Haaro
# Tuljamo
# Almo
#
#
# Iteration: 448000, Loss: 16.614766
#
# Rivurs
# Niil
# Näästela
# Rehakoski
# Vänta
# Kaa
# Turjo
# Haisto
# Tti
# Akoski
#
#
# Iteration: 450000, Loss: 16.511250
#
# Petyvuori
# Mekkahonen
# Määtti
# Pekeluri
# Vuro
# Kaa
# Tutanen
# Hakori
# To
# Aho
#
#
# Iteration: 452000, Loss: 16.816814
#
# Nivtänen
# Niihajuus
# Nättö
# Nehakoski
# Vytttojärpö
# Kaakkuka
# Turkkala
# Hahtoka
# Tukkala
# Alttea
#
#
# Iteration: 454000, Loss: 16.788797
#
# Peutto
# Meka-arula
# Mätärannel
# Pehajuuna
# Vuutanen
# Kaakonen
# Tyykkinen
# Eemosa
# Toinanen
# Aitsi
#
#
# Iteration: 456000, Loss: 16.542805
#
# Petäsoinen
# Meki-isunen
# Nyytäjäkki
# Paaherä
# Väätinen
# Jaallo-aarsisaari
# Turkkinen
# Eelopeijorero
# Tulmenkavelo
# Almikaari
#
#
# Iteration: 458000, Loss: 16.550518
#
# Olvoniemi
# Meki
# Mäsväho
# Oja
# Väsä-nilmetjärvi
# Kaakonen
# Tyäkkilä
# Haasti
# Soippo
# Allo
#
#
# Iteration: 460000, Loss: 16.703997
#
# Niutunen
# Mola
# Näytälä
# Oja
# Vuosinen
# Kaallo
# Tuokkenmar
# Ehonrainen
# Tulmanieo
# Alo-kaartio
#
#
# Iteration: 462000, Loss: 16.305574
#
# Petärnio
# Nihe
# Nävuri
# Paahesko
# Väsä-lappis
# Kaarpula
# Sutamiinen
# Haarti
# Sterankatola
# Almo
#
#
# Iteration: 464000, Loss: 16.572052
#
# Pautto
# Maja
# Mäytäkonmelä
# Paaharo
# Väsyinen
# Jaakko
# Tyykki
# Haarti
# Toinero
# Alipela
#
#
# Iteration: 466000, Loss: 16.460951
#
# Peutto
# Miek
# Näätykorpi
# Paahinmäki
# Väätkäeskiviklä
# Kaarnu
# Uusila
# Haars
# Tullangas
# Alisaahsi
#
#
# Iteration: 468000, Loss: 16.534428
#
# Olvonen
# Meke
# Märynen
# Oja
# Väsä
# Kaallo
# Sytkä
# Hajopaa
# Suljanieri
# Allo
#
#
# Iteration: 470000, Loss: 16.592964
#
# Orvoniemi
# Niek
# Näyväinen
# Ola
# Väsäinen
# Kaamonen
# Vurimaa
# Hahru
# Vunnennepaloimy
# Allo
#
#
# Iteration: 472000, Loss: 16.749821
#
# Niuttu
# Liihajärvi
# Mätyre
# Niehanoja
# Vustalahti
# Jaalopaaho
# Tyskulo
# Hakkula
# Tylninen
# Ahsola
#
#
# Iteration: 474000, Loss: 16.554599
#
# Meutto
# Kiikajärvi
# Käätujo-piivarii-olamäki
# Maaharo
# Väätsi
# Haamooja
# Sutala
# A
# Ruliala
# Airpi
#
#
# Iteration: 476000, Loss: 16.724446
#
# Pautto
# Niha
# Näyty
# Paahessaa
# Vätä-pannavalko
# Kaallun
# Tyykylähkö
# Haasti
# Sulkanlao
# Alli
#
#
# Iteration: 478000, Loss: 16.596588
#
# Meuttu
# Moijalahti
# Mättä
# Maaheso
# Vustanen
# Jaalonen
# Surjola
# Haarti
# Soinesiivainen
# Alo
#
#
# Iteration: 480000, Loss: 16.478925
#
# Petärs
# Meka
# Mäsvu
# Peidenpei
# Väsvenen
# Jaakkoka
# Sutanen
# Haiste
# Soinio
# Akora
#
#
# Iteration: 482000, Loss: 16.554436
#
# Neväänen
# Lehi
# Lussi
# Nehakoski
# Vättala
# Haakko
# Turi
# Haarraadisko
# Soikkolakko
# Akos
#
#
# Iteration: 484000, Loss: 16.468226
#
# Niäränen
# Li
# Läkoski
# Niehinoja
# Vääri
# Haalonen
# Tyhla
# Hajoo
# Tu
# Ahtu
#
#
# Iteration: 486000, Loss: 16.713923
#
# Nivustala
# Meki
# Märvä
# Neihaoma
# Vuskala
# Ieherte
# Tyngi
# Haisti
# Ttinentanen
# Alli-hantesaaro
#
#
# Iteration: 488000, Loss: 16.864926
#
# Jouvonen
# Heijainen
# Häyttila
# Kaidesmei
# Värykka
# Haakkula
# Syrjäkka
# Hajro
# Sulmerkaunmäki
# Alota
#
#
# Iteration: 490000, Loss: 16.662168
#
# Niätty
# Mielainen
# Mäytäjärvi
# Nehakoski
# Väätkä
# Jaalisaa
# Uusela
# E
# Tulkali
# Aitti
#
#
# Iteration: 492000, Loss: 16.280471
#
# Nivuro
# Meli
# Mästä
# Nehalahti
# Väräinen
# Jaalonen
# Turjola
# E
# Tulmennen
# Aitti
#
#
# Iteration: 494000, Loss: 16.833777
#
# Ninnmi
# Lehla
# Mästä
# Ne
# Vuskamaa
# Jaaklo
# Surala
# Haars
# Soirimman
# Ahti
#
#
# Iteration: 496000, Loss: 16.629377
#
# Onturo
# Meki
# Mättö
# Oja
# Vuorenen
# Kaalmäke
# Surkkanen
# Haars
# Sulkanen
# Aios
#
#
# Iteration: 498000, Loss: 16.586733
#
# Nivispellinen
# Mielajärvi
# Märvä
# Nehakoski
# Värvila
# Kaallo
# Syrhä
# Hahtola
# Stinanen
# Alapie

# %% [markdown]
# ### 4. Improvements
# - Rewrite in Keras
# - Use LSTM cell instead of RNN cell
# - Write generate function

# %% [markdown]
# #### References:
#
#     This project took inspiration from AI SW Development Hands On workshop organized by Nokia and conducted by Tarry Singh. Implementation code uses parts of code from Andrew Ng's exercise Dinosaurus Island which is a part of Deep Learning specialization at Coursera (https://www.coursera.org/specializations/deep-learning).
